# %%
import pandas as pd
btc = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/coin_Bitcoin.csv")
btc
# Out:
#        SNo     Name Symbol  ...         Close        Volume     Marketcap
# 0        1  Bitcoin    BTC  ...    144.539993  0.000000e+00  1.603769e+09
# 1        2  Bitcoin    BTC  ...    139.000000  0.000000e+00  1.542813e+09
# 2        3  Bitcoin    BTC  ...    116.989998  0.000000e+00  1.298955e+09
# 3        4  Bitcoin    BTC  ...    105.209999  0.000000e+00  1.168517e+09
# 4        5  Bitcoin    BTC  ...     97.750000  0.000000e+00  1.085995e+09
# ...    ...      ...    ...  ...           ...           ...           ...
# 2986  2987  Bitcoin    BTC  ...  33897.048590  3.872897e+10  6.354508e+11
# 2987  2988  Bitcoin    BTC  ...  34668.548402  2.438396e+10  6.499397e+11
# 2988  2989  Bitcoin    BTC  ...  35287.779766  2.492431e+10  6.615748e+11
# 2989  2990  Bitcoin    BTC  ...  33746.002456  2.672155e+10  6.326962e+11
# 2990  2991  Bitcoin    BTC  ...  34235.193451  2.650126e+10  6.418992e+11
#
# [2991 rows x 10 columns]

# %%
btc.index
# Out:
# RangeIndex(start=0, stop=2991, step=1)

# %%
btc.High
# Out:
# 0         147.488007
# 1         146.929993
# 2         139.889999
# 3         125.599998
# 4         108.127998
#             ...
# 2986    33939.588699
# 2987    34909.259899
# 2988    35937.567147
# 2989    35284.344430
# 2990    35038.536363
# Name: High, Length: 2991, dtype: float64

# %%
btc.set_index("Date")
# Out:
#                       SNo     Name  ...        Volume     Marketcap
# Date                                ...
# 2013-04-29 23:59:59     1  Bitcoin  ...  0.000000e+00  1.603769e+09
# 2013-04-30 23:59:59     2  Bitcoin  ...  0.000000e+00  1.542813e+09
# 2013-05-01 23:59:59     3  Bitcoin  ...  0.000000e+00  1.298955e+09
# 2013-05-02 23:59:59     4  Bitcoin  ...  0.000000e+00  1.168517e+09
# 2013-05-03 23:59:59     5  Bitcoin  ...  0.000000e+00  1.085995e+09
# ...                   ...      ...  ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin  ...  3.872897e+10  6.354508e+11
# 2021-07-03 23:59:59  2988  Bitcoin  ...  2.438396e+10  6.499397e+11
# 2021-07-04 23:59:59  2989  Bitcoin  ...  2.492431e+10  6.615748e+11
# 2021-07-05 23:59:59  2990  Bitcoin  ...  2.672155e+10  6.326962e+11
# 2021-07-06 23:59:59  2991  Bitcoin  ...  2.650126e+10  6.418992e+11
#
# [2991 rows x 9 columns]

# %%
btc
# Out:
#        SNo     Name Symbol  ...         Close        Volume     Marketcap
# 0        1  Bitcoin    BTC  ...    144.539993  0.000000e+00  1.603769e+09
# 1        2  Bitcoin    BTC  ...    139.000000  0.000000e+00  1.542813e+09
# 2        3  Bitcoin    BTC  ...    116.989998  0.000000e+00  1.298955e+09
# 3        4  Bitcoin    BTC  ...    105.209999  0.000000e+00  1.168517e+09
# 4        5  Bitcoin    BTC  ...     97.750000  0.000000e+00  1.085995e+09
# ...    ...      ...    ...  ...           ...           ...           ...
# 2986  2987  Bitcoin    BTC  ...  33897.048590  3.872897e+10  6.354508e+11
# 2987  2988  Bitcoin    BTC  ...  34668.548402  2.438396e+10  6.499397e+11
# 2988  2989  Bitcoin    BTC  ...  35287.779766  2.492431e+10  6.615748e+11
# 2989  2990  Bitcoin    BTC  ...  33746.002456  2.672155e+10  6.326962e+11
# 2990  2991  Bitcoin    BTC  ...  34235.193451  2.650126e+10  6.418992e+11
#
# [2991 rows x 10 columns]

# %%
btc.set_index("Date",inplace=True)

# %%
btc
# Out:
#                       SNo     Name  ...        Volume     Marketcap
# Date                                ...
# 2013-04-29 23:59:59     1  Bitcoin  ...  0.000000e+00  1.603769e+09
# 2013-04-30 23:59:59     2  Bitcoin  ...  0.000000e+00  1.542813e+09
# 2013-05-01 23:59:59     3  Bitcoin  ...  0.000000e+00  1.298955e+09
# 2013-05-02 23:59:59     4  Bitcoin  ...  0.000000e+00  1.168517e+09
# 2013-05-03 23:59:59     5  Bitcoin  ...  0.000000e+00  1.085995e+09
# ...                   ...      ...  ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin  ...  3.872897e+10  6.354508e+11
# 2021-07-03 23:59:59  2988  Bitcoin  ...  2.438396e+10  6.499397e+11
# 2021-07-04 23:59:59  2989  Bitcoin  ...  2.492431e+10  6.615748e+11
# 2021-07-05 23:59:59  2990  Bitcoin  ...  2.672155e+10  6.326962e+11
# 2021-07-06 23:59:59  2991  Bitcoin  ...  2.650126e+10  6.418992e+11
#
# [2991 rows x 9 columns]

# %%
btc.index
# Out:
# Index(['2013-04-29 23:59:59', '2013-04-30 23:59:59', '2013-05-01 23:59:59',
#        '2013-05-02 23:59:59', '2013-05-03 23:59:59', '2013-05-04 23:59:59',
#        '2013-05-05 23:59:59', '2013-05-06 23:59:59', '2013-05-07 23:59:59',
#        '2013-05-08 23:59:59',
#        ...
#        '2021-06-27 23:59:59', '2021-06-28 23:59:59', '2021-06-29 23:59:59',
#        '2021-06-30 23:59:59', '2021-07-01 23:59:59', '2021-07-02 23:59:59',
#        '2021-07-03 23:59:59', '2021-07-04 23:59:59', '2021-07-05 23:59:59',
#        '2021-07-06 23:59:59'],
#       dtype='object', name='Date', length=2991)

# %%
btc.High
# Out:
# Date
# 2013-04-29 23:59:59      147.488007
# 2013-04-30 23:59:59      146.929993
# 2013-05-01 23:59:59      139.889999
# 2013-05-02 23:59:59      125.599998
# 2013-05-03 23:59:59      108.127998
#                            ...
# 2021-07-02 23:59:59    33939.588699
# 2021-07-03 23:59:59    34909.259899
# 2021-07-04 23:59:59    35937.567147
# 2021-07-05 23:59:59    35284.344430
# 2021-07-06 23:59:59    35038.536363
# Name: High, Length: 2991, dtype: float64

# %%
btc.High.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
btc = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/coin_Bitcoin.csv")
btc.High
# Out:
# 0         147.488007
# 1         146.929993
# 2         139.889999
# 3         125.599998
# 4         108.127998
#             ...
# 2986    33939.588699
# 2987    34909.259899
# 2988    35937.567147
# 2989    35284.344430
# 2990    35038.536363
# Name: High, Length: 2991, dtype: float64

# %%
btc.High.plot()
# Out:
# <Axes: >

# %%
countries = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/world-happiness-report-2021.csv")

# %%
countries
# Out:
#     Country name  ... Dystopia + residual
# 0        Finland  ...               3.253
# 1        Denmark  ...               2.868
# 2    Switzerland  ...               2.839
# 3        Iceland  ...               2.967
# 4    Netherlands  ...               2.798
# ..           ...  ...                 ...
# 144      Lesotho  ...               1.800
# 145     Botswana  ...               0.648
# 146       Rwanda  ...               1.095
# 147     Zimbabwe  ...               1.205
# 148  Afghanistan  ...               1.895
#
# [149 rows x 20 columns]

# %%
countries["Healthy life expectancy"]
# Out:
# 0      72.000
# 1      72.700
# 2      74.400
# 3      73.000
# 4      72.400
#         ...
# 144    48.700
# 145    59.269
# 146    61.400
# 147    56.201
# 148    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
countries.set_index("Country name",inplace=True)

# %%
countries
# Out:
#               Regional indicator  ...  Dystopia + residual
# Country name                      ...
# Finland           Western Europe  ...                3.253
# Denmark           Western Europe  ...                2.868
# Switzerland       Western Europe  ...                2.839
# Iceland           Western Europe  ...                2.967
# Netherlands       Western Europe  ...                2.798
# ...                          ...  ...                  ...
# Lesotho       Sub-Saharan Africa  ...                1.800
# Botswana      Sub-Saharan Africa  ...                0.648
# Rwanda        Sub-Saharan Africa  ...                1.095
# Zimbabwe      Sub-Saharan Africa  ...                1.205
# Afghanistan           South Asia  ...                1.895
#
# [149 rows x 19 columns]

# %%
countries["Healthy life expectancy"]
# Out:
# Country name
# Finland        72.000
# Denmark        72.700
# Switzerland    74.400
# Iceland        73.000
# Netherlands    72.400
#                 ...
# Lesotho        48.700
# Botswana       59.269
# Rwanda         61.400
# Zimbabwe       56.201
# Afghanistan    52.493
# Name: Healthy life expectancy, Length: 149, dtype: float64

# %%
countries["Healthy life expectancy"].head(5).plot()
# Out:
# <Axes: xlabel='Country name'>

# %%
df = countries = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/world-happiness-report-2021.csv",index_col=0)

# %%
df
# Out:
#               Regional indicator  ...  Dystopia + residual
# Country name                      ...
# Finland           Western Europe  ...                3.253
# Denmark           Western Europe  ...                2.868
# Switzerland       Western Europe  ...                2.839
# Iceland           Western Europe  ...                2.967
# Netherlands       Western Europe  ...                2.798
# ...                          ...  ...                  ...
# Lesotho       Sub-Saharan Africa  ...                1.800
# Botswana      Sub-Saharan Africa  ...                0.648
# Rwanda        Sub-Saharan Africa  ...                1.095
# Zimbabwe      Sub-Saharan Africa  ...                1.205
# Afghanistan           South Asia  ...                1.895
#
# [149 rows x 19 columns]

# %%
df["Ladder score"]
# Out:
# Country name
# Finland        7.842
# Denmark        7.620
# Switzerland    7.571
# Iceland        7.554
# Netherlands    7.464
#                ...
# Lesotho        3.512
# Botswana       3.467
# Rwanda         3.415
# Zimbabwe       3.145
# Afghanistan    2.523
# Name: Ladder score, Length: 149, dtype: float64

# %% [markdown]
# Sort Values

# %%
Countries
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 Countries
#
# NameError: name 'Countries' is not defined

# %%
countries
# Out:
#               Regional indicator  ...  Dystopia + residual
# Country name                      ...
# Finland           Western Europe  ...                3.253
# Denmark           Western Europe  ...                2.868
# Switzerland       Western Europe  ...                2.839
# Iceland           Western Europe  ...                2.967
# Netherlands       Western Europe  ...                2.798
# ...                          ...  ...                  ...
# Lesotho       Sub-Saharan Africa  ...                1.800
# Botswana      Sub-Saharan Africa  ...                0.648
# Rwanda        Sub-Saharan Africa  ...                1.095
# Zimbabwe      Sub-Saharan Africa  ...                1.205
# Afghanistan           South Asia  ...                1.895
#
# [149 rows x 19 columns]

# %%
countries.sort_values("Healthy life expectancy")
# Out:
#                            Regional indicator  ...  Dystopia + residual
# Country name                                   ...
# Chad                       Sub-Saharan Africa  ...                3.209
# Lesotho                    Sub-Saharan Africa  ...                1.800
# Nigeria                    Sub-Saharan Africa  ...                2.736
# Ivory Coast                Sub-Saharan Africa  ...                3.469
# Swaziland                  Sub-Saharan Africa  ...                2.155
# ...                                       ...  ...                  ...
# Switzerland                    Western Europe  ...                2.839
# Spain                          Western Europe  ...                2.513
# Japan                               East Asia  ...                2.048
# Hong Kong S.A.R. of China           East Asia  ...                1.236
# Singapore                      Southeast Asia  ...                1.379
#
# [149 rows x 19 columns]

# %%
countries.sort_values("Healthy life expectancy",ascending=False)
# Out:
#                            Regional indicator  ...  Dystopia + residual
# Country name                                   ...
# Singapore                      Southeast Asia  ...                1.379
# Hong Kong S.A.R. of China           East Asia  ...                1.236
# Japan                               East Asia  ...                2.048
# Spain                          Western Europe  ...                2.513
# Switzerland                    Western Europe  ...                2.839
# ...                                       ...  ...                  ...
# Swaziland                  Sub-Saharan Africa  ...                2.155
# Ivory Coast                Sub-Saharan Africa  ...                3.469
# Nigeria                    Sub-Saharan Africa  ...                2.736
# Lesotho                    Sub-Saharan Africa  ...                1.800
# Chad                       Sub-Saharan Africa  ...                3.209
#
# [149 rows x 19 columns]

# %%
countries
# Out:
#               Regional indicator  ...  Dystopia + residual
# Country name                      ...
# Finland           Western Europe  ...                3.253
# Denmark           Western Europe  ...                2.868
# Switzerland       Western Europe  ...                2.839
# Iceland           Western Europe  ...                2.967
# Netherlands       Western Europe  ...                2.798
# ...                          ...  ...                  ...
# Lesotho       Sub-Saharan Africa  ...                1.800
# Botswana      Sub-Saharan Africa  ...                0.648
# Rwanda        Sub-Saharan Africa  ...                1.095
# Zimbabwe      Sub-Saharan Africa  ...                1.205
# Afghanistan           South Asia  ...                1.895
#
# [149 rows x 19 columns]

# %%
countries.sort_values("Healthy life expectancy",ascending=False, inplace=True)

# %%
countries
# Out:
#                            Regional indicator  ...  Dystopia + residual
# Country name                                   ...
# Singapore                      Southeast Asia  ...                1.379
# Hong Kong S.A.R. of China           East Asia  ...                1.236
# Japan                               East Asia  ...                2.048
# Spain                          Western Europe  ...                2.513
# Switzerland                    Western Europe  ...                2.839
# ...                                       ...  ...                  ...
# Swaziland                  Sub-Saharan Africa  ...                2.155
# Ivory Coast                Sub-Saharan Africa  ...                3.469
# Nigeria                    Sub-Saharan Africa  ...                2.736
# Lesotho                    Sub-Saharan Africa  ...                1.800
# Chad                       Sub-Saharan Africa  ...                3.209
#
# [149 rows x 19 columns]

# %%
houses = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/kc_house_data.csv")
titanic = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/titanic.csv")

# %%
houses
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %%
titanic
# Out:
#       pclass  survived  ... body                        home.dest
# 0          1         1  ...    ?                     St Louis, MO
# 1          1         1  ...    ?  Montreal, PQ / Chesterville, ON
# 2          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 3          1         0  ...  135  Montreal, PQ / Chesterville, ON
# 4          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# ...      ...       ...  ...  ...                              ...
# 1304       3         0  ...  328                                ?
# 1305       3         0  ...    ?                                ?
# 1306       3         0  ...  304                                ?
# 1307       3         0  ...    ?                                ?
# 1308       3         0  ...    ?                                ?
#
# [1309 rows x 14 columns]

# %%
houses.sort_values("price",ascending=False)
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 7252   6762700020  20141013T000000  ...           3940        8800
# 3914   9808700762  20140611T000000  ...           3930       25449
# 9254   9208900037  20140919T000000  ...           4540       42730
# 4411   2470100110  20140804T000000  ...           3560       24345
# 1448   8907500070  20150413T000000  ...           4600       21750
# ...           ...              ...  ...            ...         ...
# 8274   3883800011  20141105T000000  ...           1140       11250
# 16198  3028200080  20150324T000000  ...            860        9000
# 465    8658300340  20140523T000000  ...           1200        7500
# 15293    40000362  20140506T000000  ...           1700       10387
# 1149   3421079032  20150217T000000  ...           1160       42882
#
# [21613 rows x 21 columns]

# %%
houses.sort_values("bedrooms",ascending=False)
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 15870  2402100895  20140625T000000  ...           1330        4700
# 8757   1773100755  20140821T000000  ...           1420        4960
# 15161  5566100170  20141029T000000  ...           2040       11914
# 13314   627300145  20140814T000000  ...           2730       10400
# 19254  8812401450  20141229T000000  ...           1810        3745
# ...           ...              ...  ...            ...         ...
# 19452  3980300371  20140926T000000  ...           1620       22850
# 8484   2310060040  20140925T000000  ...           1810        5685
# 875    6306400140  20140612T000000  ...           2360        4000
# 8477   2569500210  20141117T000000  ...           2500        8751
# 9773   3374500520  20150429T000000  ...           2520        8050
#
# [21613 rows x 21 columns]

# %%
houses.sort_values(["bedrooms","bathrooms"],ascending=False)
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 15870  2402100895  20140625T000000  ...           1330        4700
# 8757   1773100755  20140821T000000  ...           1420        4960
# 13314   627300145  20140814T000000  ...           2730       10400
# 19254  8812401450  20141229T000000  ...           1810        3745
# 15161  5566100170  20141029T000000  ...           2040       11914
# ...           ...              ...  ...            ...         ...
# 6994   2954400190  20140624T000000  ...           4740       35061
# 9773   3374500520  20150429T000000  ...           2520        8050
# 9854   7849202190  20141223T000000  ...           1060        7200
# 14423  9543000205  20150413T000000  ...           1380        9600
# 19452  3980300371  20140926T000000  ...           1620       22850
#
# [21613 rows x 21 columns]

# %%
titanic
# Out:
#       pclass  survived  ... body                        home.dest
# 0          1         1  ...    ?                     St Louis, MO
# 1          1         1  ...    ?  Montreal, PQ / Chesterville, ON
# 2          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 3          1         0  ...  135  Montreal, PQ / Chesterville, ON
# 4          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# ...      ...       ...  ...  ...                              ...
# 1304       3         0  ...  328                                ?
# 1305       3         0  ...    ?                                ?
# 1306       3         0  ...  304                                ?
# 1307       3         0  ...    ?                                ?
# 1308       3         0  ...    ?                                ?
#
# [1309 rows x 14 columns]

# %%
titanic.head(10)
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...    ?                     St Louis, MO
# 1       1         1  ...    ?  Montreal, PQ / Chesterville, ON
# 2       1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 3       1         0  ...  135  Montreal, PQ / Chesterville, ON
# 4       1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 5       1         1  ...    ?                     New York, NY
# 6       1         1  ...    ?                       Hudson, NY
# 7       1         0  ...    ?                      Belfast, NI
# 8       1         1  ...    ?              Bayside, Queens, NY
# 9       1         0  ...   22              Montevideo, Uruguay
#
# [10 rows x 14 columns]

# %%
titanic.sort_values("name")
# Out:
#       pclass  survived  ... body                  home.dest
# 600        3         0  ...    ?                          ?
# 601        3         0  ...    ?        East Providence, RI
# 602        3         0  ...  190        East Providence, RI
# 603        3         1  ...    ?        East Providence, RI
# 604        3         1  ...    ?     Norway Los Angeles, CA
# ...      ...       ...  ...  ...                        ...
# 392        2         1  ...    ?  Lucca, Italy / California
# 1262       3         0  ...    ?                          ?
# 1263       3         0  ...    1                          ?
# 1264       3         0  ...  255                          ?
# 1268       3         0  ...    ?                          ?
#
# [1309 rows x 14 columns]

# %%
titanic.sort_values("name",key=lambda col:col.str.lower())
# Out:
#       pclass  survived  ... body               home.dest
# 600        3         0  ...    ?                       ?
# 601        3         0  ...    ?     East Providence, RI
# 602        3         0  ...  190     East Providence, RI
# 603        3         1  ...    ?     East Providence, RI
# 604        3         1  ...    ?  Norway Los Angeles, CA
# ...      ...       ...  ...  ...                     ...
# 1304       3         0  ...  328                       ?
# 1305       3         0  ...    ?                       ?
# 1306       3         0  ...  304                       ?
# 1307       3         0  ...    ?                       ?
# 1308       3         0  ...    ?                       ?
#
# [1309 rows x 14 columns]

# %%
countries
# Out:
#                            Regional indicator  ...  Dystopia + residual
# Country name                                   ...
# Singapore                      Southeast Asia  ...                1.379
# Hong Kong S.A.R. of China           East Asia  ...                1.236
# Japan                               East Asia  ...                2.048
# Spain                          Western Europe  ...                2.513
# Switzerland                    Western Europe  ...                2.839
# ...                                       ...  ...                  ...
# Swaziland                  Sub-Saharan Africa  ...                2.155
# Ivory Coast                Sub-Saharan Africa  ...                3.469
# Nigeria                    Sub-Saharan Africa  ...                2.736
# Lesotho                    Sub-Saharan Africa  ...                1.800
# Chad                       Sub-Saharan Africa  ...                3.209
#
# [149 rows x 19 columns]

# %%
countries.sort_index()
# Out:
#                               Regional indicator  ...  Dystopia + residual
# Country name                                      ...
# Afghanistan                           South Asia  ...                1.895
# Albania               Central and Eastern Europe  ...                2.250
# Algeria             Middle East and North Africa  ...                2.242
# Argentina            Latin America and Caribbean  ...                2.461
# Armenia       Commonwealth of Independent States  ...                2.127
# ...                                          ...  ...                  ...
# Venezuela            Latin America and Caribbean  ...                2.135
# Vietnam                           Southeast Asia  ...                2.211
# Yemen               Middle East and North Africa  ...                1.776
# Zambia                        Sub-Saharan Africa  ...                1.975
# Zimbabwe                      Sub-Saharan Africa  ...                1.205
#
# [149 rows x 19 columns]

# %%
countries.sort_index(ascending=False, inplace=True)

# %%
countries
# Out:
#                               Regional indicator  ...  Dystopia + residual
# Country name                                      ...
# Zimbabwe                      Sub-Saharan Africa  ...                1.205
# Zambia                        Sub-Saharan Africa  ...                1.975
# Yemen               Middle East and North Africa  ...                1.776
# Vietnam                           Southeast Asia  ...                2.211
# Venezuela            Latin America and Caribbean  ...                2.135
# ...                                          ...  ...                  ...
# Armenia       Commonwealth of Independent States  ...                2.127
# Argentina            Latin America and Caribbean  ...                2.461
# Algeria             Middle East and North Africa  ...                2.242
# Albania               Central and Eastern Europe  ...                2.250
# Afghanistan                           South Asia  ...                1.895
#
# [149 rows x 19 columns]

# %%
titanic.sort_index(ascending=False)
# Out:
#       pclass  survived  ... body                        home.dest
# 1308       3         0  ...    ?                                ?
# 1307       3         0  ...    ?                                ?
# 1306       3         0  ...  304                                ?
# 1305       3         0  ...    ?                                ?
# 1304       3         0  ...  328                                ?
# ...      ...       ...  ...  ...                              ...
# 4          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 3          1         0  ...  135  Montreal, PQ / Chesterville, ON
# 2          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 1          1         1  ...    ?  Montreal, PQ / Chesterville, ON
# 0          1         1  ...    ?                     St Louis, MO
#
# [1309 rows x 14 columns]

# %%
titanic
# Out:
#       pclass  survived  ... body                        home.dest
# 0          1         1  ...    ?                     St Louis, MO
# 1          1         1  ...    ?  Montreal, PQ / Chesterville, ON
# 2          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 3          1         0  ...  135  Montreal, PQ / Chesterville, ON
# 4          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# ...      ...       ...  ...  ...                              ...
# 1304       3         0  ...  328                                ?
# 1305       3         0  ...    ?                                ?
# 1306       3         0  ...  304                                ?
# 1307       3         0  ...    ?                                ?
# 1308       3         0  ...    ?                                ?
#
# [1309 rows x 14 columns]

# %%
titanic
# Out:
#       pclass  survived  ... body                        home.dest
# 0          1         1  ...    ?                     St Louis, MO
# 1          1         1  ...    ?  Montreal, PQ / Chesterville, ON
# 2          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 3          1         0  ...  135  Montreal, PQ / Chesterville, ON
# 4          1         0  ...    ?  Montreal, PQ / Chesterville, ON
# ...      ...       ...  ...  ...                              ...
# 1304       3         0  ...  328                                ?
# 1305       3         0  ...    ?                                ?
# 1306       3         0  ...  304                                ?
# 1307       3         0  ...    ?                                ?
# 1308       3         0  ...    ?                                ?
#
# [1309 rows x 14 columns]

# %%
titanic.pclass
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    3
# 1305    3
# 1306    3
# 1307    3
# 1308    3
# Name: pclass, Length: 1309, dtype: int64

# %%
titanic.pclass.value_counts()
# Out:
# pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
titanic.pclass.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='pclass'>

# %%
titanic.pclass.value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='pclass'>

# %%
houses.bedrooms
# Out:
# 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: bedrooms, Length: 21613, dtype: int64

# %%
houses.bedrooms.value_counts()
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64

# %%
houses.bedrooms.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='bedrooms'>

# %%
houses.bedrooms.value_counts().sort_values().plot(kind="bar")
# Out:
# <Axes: xlabel='bedrooms'>

# %%
houses.bedrooms.value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='bedrooms'>

# %% [markdown]
# LOC

# %%
countries
# Out:
#                               Regional indicator  ...  Dystopia + residual
# Country name                                      ...
# Zimbabwe                      Sub-Saharan Africa  ...                1.205
# Zambia                        Sub-Saharan Africa  ...                1.975
# Yemen               Middle East and North Africa  ...                1.776
# Vietnam                           Southeast Asia  ...                2.211
# Venezuela            Latin America and Caribbean  ...                2.135
# ...                                          ...  ...                  ...
# Armenia       Commonwealth of Independent States  ...                2.127
# Argentina            Latin America and Caribbean  ...                2.461
# Algeria             Middle East and North Africa  ...                2.242
# Albania               Central and Eastern Europe  ...                2.250
# Afghanistan                           South Asia  ...                1.895
#
# [149 rows x 19 columns]

# %%
countries["Ladder score"]
# Out:
# Country name
# Zimbabwe       3.145
# Zambia         4.073
# Yemen          3.658
# Vietnam        5.411
# Venezuela      4.892
#                ...
# Armenia        5.283
# Argentina      5.929
# Algeria        4.887
# Albania        5.117
# Afghanistan    2.523
# Name: Ladder score, Length: 149, dtype: float64

# %%
countries.head()
# Out:
#                         Regional indicator  ...  Dystopia + residual
# Country name                                ...
# Zimbabwe                Sub-Saharan Africa  ...                1.205
# Zambia                  Sub-Saharan Africa  ...                1.975
# Yemen         Middle East and North Africa  ...                1.776
# Vietnam                     Southeast Asia  ...                2.211
# Venezuela      Latin America and Caribbean  ...                2.135
#
# [5 rows x 19 columns]

# %%
countries["Ladder score"]
# Out:
# Country name
# Zimbabwe       3.145
# Zambia         4.073
# Yemen          3.658
# Vietnam        5.411
# Venezuela      4.892
#                ...
# Armenia        5.283
# Argentina      5.929
# Algeria        4.887
# Albania        5.117
# Afghanistan    2.523
# Name: Ladder score, Length: 149, dtype: float64

# %%
countries.loc['Zambia']
# Out:
# Regional indicator                            Sub-Saharan Africa
# Ladder score                                               4.073
# Standard error of ladder score                             0.069
# upperwhisker                                               4.209
# lowerwhisker                                               3.938
# Logged GDP per capita                                      8.145
# Social support                                             0.708
# Healthy life expectancy                                   55.809
# Freedom to make life choices                               0.782
# Generosity                                                 0.061
# Perceptions of corruption                                  0.823
# Ladder score in Dystopia                                    2.43
# Explained by: Log GDP per capita                           0.528
# Explained by: Social support                               0.552
# Explained by: Healthy life expectancy                      0.231
# Explained by: Freedom to make life choices                 0.487
# Explained by: Generosity                                   0.227
# Explained by: Perceptions of corruption                    0.074
# Dystopia + residual                                        1.975
# Name: Zambia, dtype: object

# %%
countries.loc["Yemen"]
# Out:
# Regional indicator                            Middle East and North Africa
# Ladder score                                                         3.658
# Standard error of ladder score                                        0.07
# upperwhisker                                                         3.794
# lowerwhisker                                                         3.521
# Logged GDP per capita                                                7.578
# Social support                                                       0.832
# Healthy life expectancy                                             57.122
# Freedom to make life choices                                         0.602
# Generosity                                                          -0.147
# Perceptions of corruption                                              0.8
# Ladder score in Dystopia                                              2.43
# Explained by: Log GDP per capita                                     0.329
# Explained by: Social support                                         0.831
# Explained by: Healthy life expectancy                                0.272
# Explained by: Freedom to make life choices                           0.268
# Explained by: Generosity                                             0.092
# Explained by: Perceptions of corruption                              0.089
# Dystopia + residual                                                  1.776
# Name: Yemen, dtype: object

# %%
countries.loc[["Yemen"]]
# Out:
#                         Regional indicator  ...  Dystopia + residual
# Country name                                ...
# Yemen         Middle East and North Africa  ...                1.776
#
# [1 rows x 19 columns]

# %%
type(countries.loc[["Yemen"]])
# Out:
# pandas.core.frame.DataFrame

# %%
type(countries.loc["Yemen"])
# Out:
# pandas.core.series.Series

# %%
countries.loc[["Canada","Mexico","United States"]]
# Out:
#                         Regional indicator  ...  Dystopia + residual
# Country name                                ...
# Canada               North America and ANZ  ...                2.585
# Mexico         Latin America and Caribbean  ...                2.961
# United States        North America and ANZ  ...                2.807
#
# [3 rows x 19 columns]

# %%
titanic.head()
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...    ?                     St Louis, MO
# 1       1         1  ...    ?  Montreal, PQ / Chesterville, ON
# 2       1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 3       1         0  ...  135  Montreal, PQ / Chesterville, ON
# 4       1         0  ...    ?  Montreal, PQ / Chesterville, ON
#
# [5 rows x 14 columns]

# %%
titanic.loc[7]
# Out:
# pclass                            1
# survived                          0
# name         Andrews, Mr. Thomas Jr
# sex                            male
# age                              39
# sibsp                             0
# parch                             0
# ticket                       112050
# fare                              0
# cabin                           A36
# embarked                          S
# boat                              ?
# body                              ?
# home.dest               Belfast, NI
# Name: 7, dtype: object

# %%
titanic.loc[[7,9,876]]
# Out:
#      pclass  survived                     name  ... boat body            home.dest
# 7         1         0   Andrews, Mr. Thomas Jr  ...    ?    ?          Belfast, NI
# 9         1         0  Artagaveytia, Mr. Ramon  ...    ?   22  Montevideo, Uruguay
# 876       3         0         Ilieff, Mr. Ylio  ...    ?    ?                    ?
#
# [3 rows x 14 columns]

# %%
titanic.loc[5:10]
# Out:
#     pclass  survived  ... body            home.dest
# 5        1         1  ...    ?         New York, NY
# 6        1         1  ...    ?           Hudson, NY
# 7        1         0  ...    ?          Belfast, NI
# 8        1         1  ...    ?  Bayside, Queens, NY
# 9        1         0  ...   22  Montevideo, Uruguay
# 10       1         0  ...  124         New York, NY
#
# [6 rows x 14 columns]

# %%
titanic.loc[5:10:2]
# Out:
#    pclass  survived                     name  ... boat body            home.dest
# 5       1         1      Anderson, Mr. Harry  ...    3    ?         New York, NY
# 7       1         0   Andrews, Mr. Thomas Jr  ...    ?    ?          Belfast, NI
# 9       1         0  Artagaveytia, Mr. Ramon  ...    ?   22  Montevideo, Uruguay
#
# [3 rows x 14 columns]

# %%
countries.sort_index(inplace=True)

# %%
countries
# Out:
#                               Regional indicator  ...  Dystopia + residual
# Country name                                      ...
# Afghanistan                           South Asia  ...                1.895
# Albania               Central and Eastern Europe  ...                2.250
# Algeria             Middle East and North Africa  ...                2.242
# Argentina            Latin America and Caribbean  ...                2.461
# Armenia       Commonwealth of Independent States  ...                2.127
# ...                                          ...  ...                  ...
# Venezuela            Latin America and Caribbean  ...                2.135
# Vietnam                           Southeast Asia  ...                2.211
# Yemen               Middle East and North Africa  ...                1.776
# Zambia                        Sub-Saharan Africa  ...                1.975
# Zimbabwe                      Sub-Saharan Africa  ...                1.205
#
# [149 rows x 19 columns]

# %%
countries.loc["Denmark":"France"]
# Out:
#                               Regional indicator  ...  Dystopia + residual
# Country name                                      ...
# Denmark                           Western Europe  ...                2.868
# Dominican Republic   Latin America and Caribbean  ...                2.178
# Ecuador              Latin America and Caribbean  ...                2.653
# Egypt               Middle East and North Africa  ...                1.648
# El Salvador          Latin America and Caribbean  ...                3.085
# Estonia               Central and Eastern Europe  ...                2.103
# Ethiopia                      Sub-Saharan Africa  ...                2.089
# Finland                           Western Europe  ...                3.253
# France                            Western Europe  ...                2.521
#
# [9 rows x 19 columns]

# %%
countries.loc["Denmark":"France":2]
# Out:
#                        Regional indicator  ...  Dystopia + residual
# Country name                               ...
# Denmark                    Western Europe  ...                2.868
# Ecuador       Latin America and Caribbean  ...                2.653
# El Salvador   Latin America and Caribbean  ...                3.085
# Ethiopia               Sub-Saharan Africa  ...                2.089
# France                     Western Europe  ...                2.521
#
# [5 rows x 19 columns]

# %%
countries.loc["France":"Denmark"]
# Out:
# Empty DataFrame
# Columns: [Regional indicator, Ladder score, Standard error of ladder score, upperwhisker, lowerwhisker, Logged GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption, Ladder score in Dystopia, Explained by: Log GDP per capita, Explained by: Social support, Explained by: Healthy life expectancy, Explained by: Freedom to make life choices, Explained by: Generosity, Explained by: Perceptions of corruption, Dystopia + residual]
# Index: []

# %%
countries
# Out:
#                               Regional indicator  ...  Dystopia + residual
# Country name                                      ...
# Afghanistan                           South Asia  ...                1.895
# Albania               Central and Eastern Europe  ...                2.250
# Algeria             Middle East and North Africa  ...                2.242
# Argentina            Latin America and Caribbean  ...                2.461
# Armenia       Commonwealth of Independent States  ...                2.127
# ...                                          ...  ...                  ...
# Venezuela            Latin America and Caribbean  ...                2.135
# Vietnam                           Southeast Asia  ...                2.211
# Yemen               Middle East and North Africa  ...                1.776
# Zambia                        Sub-Saharan Africa  ...                1.975
# Zimbabwe                      Sub-Saharan Africa  ...                1.205
#
# [149 rows x 19 columns]

# %%
countries.iloc[[0]]
# Out:
#              Regional indicator  ...  Dystopia + residual
# Country name                     ...
# Afghanistan          South Asia  ...                1.895
#
# [1 rows x 19 columns]

# %%
countries.iloc[[10,20,30,100]]
# Out:
#                               Regional indicator  ...  Dystopia + residual
# Country name                                      ...
# Belarus       Commonwealth of Independent States  ...                2.247
# Cambodia                          Southeast Asia  ...                2.148
# Croatia               Central and Eastern Europe  ...                2.325
# Nigeria                       Sub-Saharan Africa  ...                2.736
#
# [4 rows x 19 columns]

# %%
countries.iloc[50:60]
# Out:
#                                      Regional indicator  ...  Dystopia + residual
# Country name                                             ...
# Haiti                       Latin America and Caribbean  ...                2.060
# Honduras                    Latin America and Caribbean  ...                2.934
# Hong Kong S.A.R. of China                     East Asia  ...                1.236
# Hungary                      Central and Eastern Europe  ...                2.432
# Iceland                                  Western Europe  ...                2.967
# India                                        South Asia  ...                1.405
# Indonesia                                Southeast Asia  ...                1.987
# Iran                       Middle East and North Africa  ...                1.823
# Iraq                       Middle East and North Africa  ...                2.429
# Ireland                                  Western Europe  ...                2.384
#
# [10 rows x 19 columns]

# %%
houses
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 0      7129300520  20141013T000000  ...           1340        5650
# 1      6414100192  20141209T000000  ...           1690        7639
# 2      5631500400  20150225T000000  ...           2720        8062
# 3      2487200875  20141209T000000  ...           1360        5000
# 4      1954400510  20150218T000000  ...           1800        7503
# ...           ...              ...  ...            ...         ...
# 21608   263000018  20140521T000000  ...           1530        1509
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21611   291310100  20150116T000000  ...           1410        1287
# 21612  1523300157  20141015T000000  ...           1020        1357
#
# [21613 rows x 21 columns]

# %%
houses.sort_index(ascending=False,inplace=True)

# %%
houses
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 21612  1523300157  20141015T000000  ...           1020        1357
# 21611   291310100  20150116T000000  ...           1410        1287
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21608   263000018  20140521T000000  ...           1530        1509
# ...           ...              ...  ...            ...         ...
# 4      1954400510  20150218T000000  ...           1800        7503
# 3      2487200875  20141209T000000  ...           1360        5000
# 2      5631500400  20150225T000000  ...           2720        8062
# 1      6414100192  20141209T000000  ...           1690        7639
# 0      7129300520  20141013T000000  ...           1340        5650
#
# [21613 rows x 21 columns]

# %%
houses.iloc[0:5]
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 21612  1523300157  20141015T000000  ...           1020        1357
# 21611   291310100  20150116T000000  ...           1410        1287
# 21610  1523300141  20140623T000000  ...           1020        2007
# 21609  6600060120  20150223T000000  ...           1830        7200
# 21608   263000018  20140521T000000  ...           1530        1509
#
# [5 rows x 21 columns]

# %%
houses.loc[21612:21611]
# Out:
#                id             date  ...  sqft_living15  sqft_lot15
# 21612  1523300157  20141015T000000  ...           1020        1357
# 21611   291310100  20150116T000000  ...           1410        1287
#
# [2 rows x 21 columns]

# %%
houses.loc[21612:21611,['price','bedrooms']]
# Out:
#           price  bedrooms
# 21612  325000.0         2
# 21611  400000.0         3

# %%
titanic.loc[50:60:2,['name','sex','age']]
# Out:
#                                                  name     sex age
# 50  Cardeza, Mrs. James Warburton Martinez (Charlo...  female  58
# 52                            Carrau, Mr. Francisco M    male  28
# 54                Carter, Master. William Thornton II    male  11
# 56                         Carter, Mr. William Ernest    male  36
# 58                             Case, Mr. Howard Brown    male  49
# 60                      Cavendish, Mr. Tyrell William    male  36

# %%
countries.loc["Canada":"Denmark",['Ladder score']]
# Out:
#                      Ladder score
# Country name
# Canada                      7.103
# Chad                        4.355
# Chile                       6.172
# China                       5.339
# Colombia                    6.012
# Comoros                     4.289
# Congo (Brazzaville)         5.342
# Costa Rica                  7.069
# Croatia                     5.882
# Cyprus                      6.223
# Czech Republic              6.965
# Denmark                     7.620

# %%
countries.loc["Canada":"Denmark"]['Ladder score']
# Out:
# Country name
# Canada                 7.103
# Chad                   4.355
# Chile                  6.172
# China                  5.339
# Colombia               6.012
# Comoros                4.289
# Congo (Brazzaville)    5.342
# Costa Rica             7.069
# Croatia                5.882
# Cyprus                 6.223
# Czech Republic         6.965
# Denmark                7.620
# Name: Ladder score, dtype: float64

# %%
houses["bedrooms"].value_counts()
# Out:
# bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 33       1
# 11       1
# Name: count, dtype: int64

# %%
houses["bedrooms"].value_counts().iloc[0]
# Out:
# 9824

# %%
houses["bedrooms"].value_counts().iloc[0:3]
# Out:
# bedrooms
# 3    9824
# 4    6882
# 2    2760
# Name: count, dtype: int64

# %%
houses["bedrooms"].value_counts().loc[33]
# Out:
# 1

# %%
titanic["age"].value_counts().loc[18]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 18
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 titanic["age"].value_counts().loc[18]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# -> 1343     return self.obj.xs(label, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:4236, in NDFrame.xs(self, key, axis, level, drop_level)
#    4234             new_index = index[loc]
#    4235 else:
# -> 4236     loc = index.get_loc(key)
#    4238     if isinstance(loc, np.ndarray):
#    4239         if loc.dtype == np.bool_:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 18

# %%
titanic["age"].value_counts().loc["18"]
# Out:
# 39

# %%
titanic["age"].value_counts().iloc[0:5]
# Out:
# age
# ?     263
# 24     47
# 22     43
# 21     41
# 30     40
# Name: count, dtype: int64
