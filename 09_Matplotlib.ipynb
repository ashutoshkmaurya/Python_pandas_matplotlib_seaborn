# %%
import matplotlib.pyplot as plt

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([2,3,5,6])

# %%
salaries = [10000,55000,30000,42000,15000,25000]
ages = [20,25,30,32,40,45]
plt.plot(ages,salaries)

# %%
import matplotlib.pyplot as plt

salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]

plt.plot(ages, salaries, marker='o', linestyle='-')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Salary vs Age')
plt.grid(True)
plt.show()

# %% [markdown]
# *Topic : Matplotlib.pyplot.show below :

# %%
import numpy as np

# %%
nums = np.arange(1,6)

# %%
nums
# Out:
# array([1, 2, 3, 4, 5])

# %%
nums2 = nums * 2
nums2
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
plt.plot(nums,nums )
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.figure()
plt.plot(nums,nums )
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.figure()
plt.plot(nums,nums )
plt.figure()
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.figure()
plt.plot(nums,nums)
plt.figure()
plt.plot(nums,nums*nums)
plt.figure()
plt.plot(nums,nums**3)

# %%
plt.figure(figsize=(2,6))

# %%
plt.figure(figsize=(2,6))
plt.plot(nums,nums)

# %%
plt.figure(figsize=(20,6))
plt.plot(nums,nums)

# %%
plt.figure(figsize=(10,6),dpi=200)
plt.plot(nums,nums)

# %%
plt.figure(figsize=(10,6),dpi=20)
plt.plot(nums,nums)

# %%
plt.figure(figsize=(10,6),dpi=20)
plt.plot(nums,nums)
plt.figure(figsize=(10,6),dpi=20)
plt.plot(nums,nums*nums)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("fivethirtyeight")

# %%
plt.plot(nums,nums)
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.style.use('seaborn-v0_8')

# %%
plt.plot(nums,nums)
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.style.use('Solarize_Light2')

# %%
plt.plot(nums,nums)
plt.plot(nums,nums*nums)
plt.plot(nums,nums**3)

# %%
plt.style.use('ggplot')

# %%
plt.plot(nums,nums,color="olive",linewidth=5,linestyle = "dashed")
plt.plot(nums,nums*nums, color="#ff6b6b",linewidth=5, linestyle="dotted")
plt.plot(nums,nums**3, c = "#ff9f43", linewidth=5, linestyle="--")

# %%
plt.plot(nums,nums,color="olive",linewidth=2,marker=">")

# %%
plt.plot(nums,nums,color="olive",linewidth=1,marker="*")

# %%
plt.plot(nums,nums,color="olive",linewidth=1,marker="*",markersize=15)

# %%
plt.plot(nums,nums,color="olive",linewidth=1,marker="*",markersize=15, markerfacecolor="blue")

# %%
salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]
plt.plot(ages,salaries)

# %%
salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]
plt.plot(ages,salaries)
plt.title("Age vs Salaries")
# Out:
# Text(0.5, 1.0, 'Age vs Salaries')

# %%
salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]
plt.plot(ages,salaries)
plt.title("Age vs Salaries")
# Out:
# Text(0.5, 1.0, 'Age vs Salaries')

# %%
salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]
plt.plot(ages,salaries)
plt.title("Age vs Salaries")
plt.figure()
plt.title("Linear Stuff",loc="Left")
plt.plot(nums,nums,color="olive",linewidth=1,marker="*",markersize=15, markerfacecolor="blue")

# %%
salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]
plt.plot(ages,salaries)
plt.title("Age vs Salaries")
plt.xlabel("Employee Age")
# Out:
# Text(0.5, 0, 'Employee Age')

# %%
salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]
plt.plot(ages,salaries)
plt.title("Age vs Salaries")
plt.xlabel("Employee Age", labelpad=10)
# Out:
# Text(0.5, 0, 'Employee Age')

# %%
salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]
plt.plot(ages,salaries)
plt.title("Age vs Salaries", fontsize = 20, color = "red")
plt.xlabel("Employee Age", labelpad=10, fontsize = 15)
plt.ylabel("Average Salary",labelpad=10, fontsize = 15)
# Out:
# Text(0, 0.5, 'Average Salary')

# %%
plt.figure(figsize=(5,5))
salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]
plt.plot(ages,salaries)
plt.title("Age vs Salaries", fontsize = 20, color = "red")
plt.xlabel("Employee Age", labelpad=10, fontsize = 15)
plt.ylabel("Average Salary",labelpad=10, fontsize = 15)
plt.xticks([20,25,30,35,40,45])
# Out:
# ([<matplotlib.axis.XTick at 0x27e84164310>,
# ...
#  [Text(20, 0, '20'),
#   Text(25, 0, '25'),
#   Text(30, 0, '30'),
#   Text(35, 0, '35'),
#   Text(40, 0, '40'),
#   Text(45, 0, '45')])

# %%
plt.figure(figsize=(5,5))
salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]
plt.plot(ages,salaries)
plt.title("Age vs Salaries", fontsize = 20, color = "red")
plt.xlabel("Employee Age", labelpad=10, fontsize = 15)
plt.ylabel("Average Salary",labelpad=10, fontsize = 15)
plt.xticks([20,25,30,35,40,45])
plt.yticks([10000,20000,30000,40000,50000,60000])
# Out:
# ([<matplotlib.axis.YTick at 0x27efe972950>,
# ...
#  [Text(0, 10000, '10000'),
#   Text(0, 20000, '20000'),
#   Text(0, 30000, '30000'),
#   Text(0, 40000, '40000'),
#   Text(0, 50000, '50000'),
#   Text(0, 60000, '60000')])

# %%
plt.figure(figsize=(5,5))
salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]
plt.plot(ages,salaries)
plt.title("Age vs Salaries", fontsize = 20, color = "red")
plt.xlabel("Employee Age", labelpad=10, fontsize = 15)
plt.ylabel("Average Salary",labelpad=10, fontsize = 15)
plt.xticks([20,25,30,35,40,45])
plt.yticks([10000,20000,30000,40000,50000,60000], labels=["10K","20K","30K","40K","50K","60K"])
# Out:
# ([<matplotlib.axis.YTick at 0x27e89142550>,
# ...
#  [Text(0, 10000, '10K'),
#   Text(0, 20000, '20K'),
#   Text(0, 30000, '30K'),
#   Text(0, 40000, '40K'),
#   Text(0, 50000, '50K'),
#   Text(0, 60000, '60K')])

# %%
plt.figure(figsize=(5,5))
salaries = [10000, 55000, 30000, 42000, 15000, 25000]
ages = [20, 25, 30, 32, 40, 45]
plt.plot(ages,salaries)
plt.xlim(25,40)
plt.ylim(20000,40000)
# Out:
# (20000.0, 40000.0)

# %% [markdown]
# Adding Legends to plot

# %%
plt.figure(figsize=(8,8))

# %%
plt.figure(figsize=(5,5))
plt.plot(nums,color="teal",label = "x")
plt.plot(nums**2,color="olive",label="x squared")
plt.plot(nums**3,color="purple",label="x cubed")
plt.legend()

# %%
plt.figure(figsize=(5,5))
plt.plot(nums,color="teal",label = "x")
plt.plot([60,50,40,30,20,10], color = "purple",label="x cubed")
plt.plot(nums**2,color="olive",label="x squared")
plt.plot(nums**3,color="purple",label="x cubed")
plt.legend()

# %%
plt.figure(figsize=(5,5))
plt.plot(nums,color="teal",label = "x")
plt.plot([60,50,40,30,20,10], color = "purple",label="x cubed")
plt.plot(nums**2,color="olive",label="x squared")
plt.plot(nums**3,color="purple",label="x cubed")
plt.legend(loc="upper left")

# %%
plt.figure(figsize=(5,5))
plt.plot(nums,color="teal",label = "x")
plt.plot(nums**2,color="olive",label="x squared")
plt.plot(nums**3,color="purple",label="x cubed")
plt.legend(loc="upper left", shadow = True, frameon = True)

# %%
plants = ['Spinach','Turnip','Rhubarb','Broccoli','Kale']
died = [10,25,5,30,21]
germinated = [74,88,56,69,59]

# %%
plt.figure(figsize=(6,6))
plt.bar(plants,germinated)
plt.title("Germination Rates")
plt.ylabel("Number of Seedlings")
# Out:
# Text(0, 0.5, 'Number of Seedlings')

# %%
plt.figure(figsize=(6,6))
plt.bar(plants,germinated, width = 0.5)
plt.title("Germination Rates")
plt.ylabel("Number of Seedlings")
# Out:
# Text(0, 0.5, 'Number of Seedlings')

# %%
plt.figure(figsize=(6,6))
plt.bar(plants,germinated, width = 0.5, color="orchid")
plt.title("Germination Rates")
plt.ylabel("Number of Seedlings")
# Out:
# Text(0, 0.5, 'Number of Seedlings')

# %%
plt.figure(figsize=(6,6))
plt.bar(plants,died, width = 0.5, color="red")
plt.title("Faiure Rates")
plt.ylabel("Number of Seedlings")
# Out:
# Text(0, 0.5, 'Number of Seedlings')

# %%
plt.figure(figsize=(6,6))
plt.bar(plants,died, color = "#e74c3c")
plt.bar(plants,germinated, width =0.4, color = "#2ecc71", align = "edge")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(6,6))
plt.bar(plants,died, color = "#e74c3c",bottom=germinated, label = "Failed Seedlings")
plt.bar(plants,germinated, color = "#2ecc71", label = "Germinated Seedlings")
plt.legend()

# %%
plt.figure(figsize=(6,6))
plt.bar(plants,died, color = "#e74c3c",bottom=germinated, label = "Failed Seedlings")
plt.bar(plants,germinated, color = "#2ecc71", label = "Germinated Seedlings")
plt.legend()

# %%
plt.figure(figsize=(6,6))
plt.bar(plants,died, color = "#e74c3c",bottom=germinated, label = "Failed Seedlings")
plt.bar(plants,germinated, color = "#2ecc71", label = "Germinated Seedlings")
plt.legend()
plt.title("Greenhouse Seedlings")
plt.show()

# %%
plt.figure(figsize = (6,6))
plt.barh(plants,germinated,color = "#2ecc71")
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# *histogram

# %%
plt.hist([1,1,2,3,3,3,3,3,1])
# Out:
# (array([3., 0., 0., 0., 0., 1., 0., 0., 0., 5.]),
#  array([1. , 1.2, 1.4, 1.6, 1.8, 2. , 2.2, 2.4, 2.6, 2.8, 3. ]),
#  <BarContainer object of 10 artists>)

# %%
nums = np.random.randn(100)

# %%
plt.hist(nums)
# Out:
# (array([ 1.,  5.,  6., 14., 13., 21., 19.,  6.,  8.,  7.]),
#  array([-2.37914342, -1.92483547, -1.47052752, -1.01621957, -0.56191162,
#         -0.10760368,  0.34670427,  0.80101222,  1.25532017,  1.70962812,
#          2.16393607]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(nums,bins=20)
# Out:
# (array([ 1.,  0.,  0.,  5.,  3.,  3.,  4., 10.,  4.,  9., 10., 11., 10.,
#          9.,  4.,  2.,  5.,  3.,  2.,  5.]),
#  array([-2.37914342, -2.15198945, -1.92483547, -1.6976815 , -1.47052752,
#         -1.24337355, -1.01621957, -0.7890656 , -0.56191162, -0.33475765,
#         -0.10760368,  0.1195503 ,  0.34670427,  0.57385825,  0.80101222,
#          1.0281662 ,  1.25532017,  1.48247415,  1.70962812,  1.9367821 ,
#          2.16393607]),
#  <BarContainer object of 20 artists>)

# %%
import pandas as pd
titanic = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/titanic.csv")
titanic["age"]= pd.to_numeric(titanic["age"],errors = "coerce")

# %%
titanic.age
# Out:
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
#          ...
# 1304    14.5000
# 1305        NaN
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
# Name: age, Length: 1309, dtype: float64

# %%
plt.hist(titanic["age"])
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.1667 ,  8.15003, 16.13336, 24.11669, 32.10002, 40.08335,
#         48.06668, 56.05001, 64.03334, 72.01667, 80.     ]),
#  <BarContainer object of 10 artists>)

# %%
first_class = titanic[titanic["pclass"]==1]["age"]
plt.hist(first_class)
# Out:
# (array([ 4.,  7., 42., 46., 56., 50., 44., 27.,  6.,  2.]),
#  array([ 0.9167 ,  8.82503, 16.73336, 24.64169, 32.55002, 40.45835,
#         48.36668, 56.27501, 64.18334, 72.09167, 80.     ]),
#  <BarContainer object of 10 artists>)

# %%
first_class = titanic[titanic["pclass"]==1]["age"]
second_class = titanic[titanic["pclass"]==2]["age"]
plt.hist(first_class)
plt.figure()
plt.hist(second_class)
# Out:
# (array([18.,  9., 36., 67., 59., 32., 15., 13., 10.,  2.]),
#  array([ 0.6667 ,  7.60003, 14.53336, 21.46669, 28.40002, 35.33335,
#         42.26668, 49.20001, 56.13334, 63.06667, 70.     ]),
#  <BarContainer object of 10 artists>)

# %%
first_class = titanic[titanic["pclass"]==1]["age"]
second_class = titanic[titanic["pclass"]==2]["age"]
plt.hist(first_class)
plt.hist(second_class)
# Out:
# (array([18.,  9., 36., 67., 59., 32., 15., 13., 10.,  2.]),
#  array([ 0.6667 ,  7.60003, 14.53336, 21.46669, 28.40002, 35.33335,
#         42.26668, 49.20001, 56.13334, 63.06667, 70.     ]),
#  <BarContainer object of 10 artists>)

# %%
first_class = titanic[titanic["pclass"]==1]["age"]
second_class = titanic[titanic["pclass"]==2]["age"]
plt.hist(first_class, label="1st Class")
plt.hist(second_class, label="2nd Class")
plt.legend()

# %%
first_class = titanic[titanic["pclass"]== 1]["age"]
second_class = titanic[titanic["pclass"]== 2]["age"]
third_class = titanic[titanic["pclass"]== 3]["age"]
plt.hist(first_class, label="1st Class", alpha = 0.5, color="#f1c40f", bins = 20)
plt.hist(second_class, label="2nd Class", alpha = 0.5, color="#3498db", bins = 20)
plt.hist(third_class, label="3rd Class", alpha = 0.5, color="#e74c3c", bins = 20)
plt.legend()
plt.title("Titanic Passenger Ages")
plt.xlabel("Passenger Age")
# Out:
# Text(0.5, 0, 'Passenger Age')

# %% [markdown]
# Scatter plot

# %%
heights = [137,140,142,145,147,150,152,155,157,160]
f_weights = [28.5,30.8,32.6,34.9,36.4,39,40.8,43.1,44.9,47.2]
m_weights = [34.9,38.1,33.5,35.8,46.7,42.8,43.1,45.8,50.8,58.9]

# %%
plt.scatter(heights,f_weights)

# %%
plt.scatter(f_weights,heights,c = "purple")

# %%
plt.scatter(f_weights,heights,c = "purple", marker="*")

# %%
plt.scatter(heights,f_weights, marker="*")
plt.scatter(heights,m_weights, marker="d")

# %%
plt.scatter(heights,f_weights, marker="*", label = "Female")
plt.scatter(heights,m_weights, marker="d", label = "Male")
plt.legend()
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
# Out:
# Text(0, 0.5, 'Weight (kg)')

# %% [markdown]
# Pie Charts

# %%
labels = ["Turkey","Potatoes","Pumpkin Pie", "Stuffing"]
prices = [25.99,3.24,9.50,6.99]

# %%
plt.pie(prices)
# Out:
# ([<matplotlib.patches.Wedge at 0x2b5f7272f90>,
# ...
#  [Text(-0.23476164907796612, 1.0746566745347996, ''),
#   Text(-0.873837836440518, -0.668137287991738, ''),
#   Text(-0.04684884939109384, -1.0990019041433599, ''),
#   Text(0.9755372148905609, -0.5082589323991933, '')])

# %%
plt.pie(prices,labels=labels)
plt.show()

# %%
plt.pie(prices,labels=labels, autopct="%1.1f")
plt.show()

# %%
plt.pie(prices,labels=labels, autopct="%1.1f", shadow=True)
plt.show()

# %%
plt.pie(prices,labels=labels, autopct="%1.1f", shadow=True,explode=(0,0,0.1,0))
plt.show()

# %% [markdown]
# -------------------------------------------
#
#
#
#
#
# Subplots

# %%
nums = np.arange(5)
plt.figure(figsize=(10,4))
plt.plot(nums, nums)

# %%
nums = np.arange(5)
plt.figure(figsize=(10,4))
plt.suptitle("Our First Subplot",fontsize=30)

plt.subplot(1,3,1)
plt.title("X")
plt.plot(nums, nums)

plt.subplot(1,3,2)
plt.title("X Squared")
plt.plot(nums,nums**2, color = "red")

plt.subplot(1,3,3)
plt.title("X Cubed")
plt.plot(nums, nums**3, color="yellow")
plt.tight_layout()
plt.show()

# %%
nums = np.arange(5)
plt.figure(figsize=(4,10))
plt.suptitle("Our First Subplot",fontsize=30)

plt.subplot(3,1,1)
plt.title("X")
plt.plot(nums, nums)

plt.subplot(3,1,2)
plt.title("X Squared")
plt.plot(nums,nums**2, color = "red")

plt.subplot(3,1,3)
plt.title("X Cubed")
plt.plot(nums, nums**3, color="yellow")
plt.tight_layout()
plt.show()

# %%
nums = np.arange(5)
plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
plt.plot(nums)

plt.subplot(2,2,2)
plt.plot(nums**2)

plt.subplot(2,2,3)
plt.plot(nums**3)

plt.subplot(2,2,4)
plt.plot(nums**4)

# %%
first_class = titanic[titanic["pclass"]== 1]["age"]
second_class = titanic[titanic["pclass"]== 2]["age"]
third_class = titanic[titanic["pclass"]== 3]["age"]

plt.figure(figsize=(10,4))
plt.subplot(1,3,1)
plt.hist(first_class, label="1st Class",  color="#f1c40f", bins = 20)
plt.title("1st class")

plt.subplot(1,3,2)
plt.hist(second_class, label="2nd Class", color="#3498db", bins = 20)
plt.title("2nd class")

plt.subplot(1,3,3)
plt.hist(third_class, label="3rd Class",  color="#e74c3c", bins = 20)
plt.title("3rd class")
# Out:
# Text(0.5, 1.0, '3rd class')

# %%
first_class = titanic[titanic["pclass"]== 1]["age"]
second_class = titanic[titanic["pclass"]== 2]["age"]
third_class = titanic[titanic["pclass"]== 3]["age"]

plt.figure(figsize=(10,4))
ax = plt.subplot(1,3,1)
plt.hist(first_class, label="1st Class",  color="#f1c40f", bins = 20)
plt.title("1st class")

plt.subplot(1,3,2, sharey=ax)
plt.hist(second_class, label="2nd Class", color="#3498db", bins = 20)
plt.title("2nd class")

plt.subplot(1,3,3,sharey=ax)
plt.hist(third_class, label="3rd Class",  color="#e74c3c", bins = 20)
plt.title("3rd class")
plt.show()
