# %% [markdown]
# The String Data Type vs Object Datatype

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/titanic.csv")
titanic['age'] = titanic['age'].replace(['?'],[None]).astype('float')
titanic['fare'] = titanic['fare'].replace(['?'],[None]).astype('float')

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(2), int64(4), object(8)
# memory usage: 143.3+ KB

# %%
titanic.name.astype("string")
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: string

# %%
titanic.name.astype("string")[0]
# Out:
# 'Allen, Miss. Elisabeth Walton'

# %% [markdown]
# --------------------------------
# -----------------------------
# ----------------------------
#
# Upper() , Lower(), Capitalize()

# %%
titanic["name"]
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
"Hello".upper()
# Out:
# 'HELLO'

# %%
"Hello".lower()
# Out:
# 'hello'

# %%
titanic["name"].upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20284\4097369267.py in ?()
# ----> 1 titanic["name"].upper()
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
titanic["name"].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20284\39098804.py in ?()
# ----> 1 titanic["name"].lower()
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
titanic["name"].str.upper()
# Out:
# 0                         ALLEN, MISS. ELISABETH WALTON
# 1                        ALLISON, MASTER. HUDSON TREVOR
# 2                          ALLISON, MISS. HELEN LORAINE
# 3                  ALLISON, MR. HUDSON JOSHUA CREIGHTON
# 4       ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)
#                              ...
# 1304                               ZABOUR, MISS. HILENI
# 1305                              ZABOUR, MISS. THAMINE
# 1306                          ZAKARIAN, MR. MAPRIEDEDER
# 1307                                ZAKARIAN, MR. ORTIN
# 1308                                 ZIMMERMAN, MR. LEO
# Name: name, Length: 1309, dtype: object

# %%
titanic["name"]
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic["name"].str.lower()
# Out:
# 0                         allen, miss. elisabeth walton
# 1                        allison, master. hudson trevor
# 2                          allison, miss. helen loraine
# 3                  allison, mr. hudson joshua creighton
# 4       allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               zabour, miss. hileni
# 1305                              zabour, miss. thamine
# 1306                          zakarian, mr. mapriededer
# 1307                                zakarian, mr. ortin
# 1308                                 zimmerman, mr. leo
# Name: name, Length: 1309, dtype: object

# %%
titanic["lower_name"] = titanic["name"].str.lower()

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.lower_name.str.capitalize()
# Out:
# 0                         Allen, miss. elisabeth walton
# 1                        Allison, master. hudson trevor
# 2                          Allison, miss. helen loraine
# 3                  Allison, mr. hudson joshua creighton
# 4       Allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               Zabour, miss. hileni
# 1305                              Zabour, miss. thamine
# 1306                          Zakarian, mr. mapriededer
# 1307                                Zakarian, mr. ortin
# 1308                                 Zimmerman, mr. leo
# Name: lower_name, Length: 1309, dtype: object

# %% [markdown]
# ------------------------------------------
# ------------------------------------------
# -------------------------------------------
# Indexing String Series with []

# %%
"hello"[0]
# Out:
# 'h'

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["cabin"].str[0]
# Out:
# 0       B
# 1       C
# 2       C
# 3       C
# 4       C
#        ..
# 1304    ?
# 1305    ?
# 1306    ?
# 1307    ?
# 1308    ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic["deck"] = titanic["cabin"].str[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df = titanic[["pclass","survived","age","sibsp","parch","fare","deck"]]

# %%
df
# Out:
#       pclass  survived      age  sibsp  parch      fare deck
# 0          1         1  29.0000      0      0  211.3375    B
# 1          1         1   0.9167      1      2  151.5500    C
# 2          1         0   2.0000      1      2  151.5500    C
# 3          1         0  30.0000      1      2  151.5500    C
# 4          1         0  25.0000      1      2  151.5500    C
# ...      ...       ...      ...    ...    ...       ...  ...
# 1304       3         0  14.5000      1      0   14.4542    ?
# 1305       3         0      NaN      1      0   14.4542    ?
# 1306       3         0  26.5000      0      0    7.2250    ?
# 1307       3         0  27.0000      0      0    7.2250    ?
# 1308       3         0  29.0000      0      0    7.8750    ?
#
# [1309 rows x 7 columns]

# %%
df.groupby("deck").mean()
# Out:
#         pclass  survived        age     sibsp     parch        fare
# deck
# ?     2.617357  0.302761  27.406654  0.503945  0.367850   19.132707
# A     1.000000  0.500000  44.157895  0.181818  0.181818   41.244314
# B     1.000000  0.723077  36.476190  0.446154  0.661538  122.383078
# C     1.000000  0.606383  38.382752  0.680851  0.414894  107.926598
# D     1.130435  0.695652  39.702381  0.413043  0.260870   53.007339
# E     1.243902  0.731707  38.118421  0.341463  0.390244   54.564634
# F     2.380952  0.619048  21.333333  0.428571  0.523810   18.079367
# G     3.000000  0.600000  12.000000  0.600000  1.200000   14.205000
# T     1.000000  0.000000  45.000000  0.000000  0.000000   35.500000

# %%
df.groupby("deck")["survived"].mean()
# Out:
# deck
# ?    0.302761
# A    0.500000
# B    0.723077
# C    0.606383
# D    0.695652
# E    0.731707
# F    0.619048
# G    0.600000
# T    0.000000
# Name: survived, dtype: float64

# %%
df.groupby("deck")["survived"].mean().plot(kind = "bar")
# Out:
# <Axes: xlabel='deck'>

# %%
df.groupby("deck")["survived"].mean().sort_values().plot(kind = "bar")
# Out:
# <Axes: xlabel='deck'>

# %%
titanic.cabin
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304          ?
# 1305          ?
# 1306          ?
# 1307          ?
# 1308          ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic.cabin.str[1:]
# Out:
# 0            5
# 1       22 C26
# 2       22 C26
# 3       22 C26
# 4       22 C26
#          ...
# 1304
# 1305
# 1306
# 1307
# 1308
# Name: cabin, Length: 1309, dtype: object

# %%
s = pd.Series(['1.Hawk.    ', '2.Pickle!\n', '3. Melonhead\t'])

# %%
s
# Out:
# 0       1.Hawk.
# 1       2.Pickle!\n
# 2    3. Melonhead\t
# dtype: object

# %%
s.str.strip()
# Out:
# 0         1.Hawk.
# 1       2.Pickle!
# 2    3. Melonhead
# dtype: object

# %%
s.str.strip(to_strip="1")
# Out:
# 0        .Hawk.
# 1       2.Pickle!\n
# 2    3. Melonhead\t
# dtype: object

# %%
s.str.strip(to_strip="12")
# Out:
# 0        .Hawk.
# 1        .Pickle!\n
# 2    3. Melonhead\t
# dtype: object

# %%
s.str.strip(to_strip="123.")
# Out:
# 0       Hawk.
# 1       Pickle!\n
# 2     Melonhead\t
# dtype: object

# %%
s.str.strip(to_strip="123. ")
# Out:
# 0           Hawk
# 1      Pickle!\n
# 2    Melonhead\t
# dtype: object

# %%
s.str.strip(to_strip="123. \n \t")
# Out:
# 0         Hawk
# 1      Pickle!
# 2    Melonhead
# dtype: object

# %%
s.str.rstrip()
# Out:
# 0         1.Hawk.
# 1       2.Pickle!
# 2    3. Melonhead
# dtype: object

# %%
s.str.lstrip()
# Out:
# 0       1.Hawk.
# 1       2.Pickle!\n
# 2    3. Melonhead\t
# dtype: object

# %%
s.str.lstrip(to_strip="123.")
# Out:
# 0       Hawk.
# 1       Pickle!\n
# 2     Melonhead\t
# dtype: object

# %% [markdown]
# ------------------------------------
# ------------------------------------
#
# ---------------------------------------
# Splitting Text values with Split()

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["home.dest"]
# Out:
# 0                          St Louis, MO
# 1       Montreal, PQ / Chesterville, ON
# 2       Montreal, PQ / Chesterville, ON
# 3       Montreal, PQ / Chesterville, ON
# 4       Montreal, PQ / Chesterville, ON
#                      ...
# 1304                                  ?
# 1305                                  ?
# 1306                                  ?
# 1307                                  ?
# 1308                                  ?
# Name: home.dest, Length: 1309, dtype: object

# %%
titanic["home.dest"].str.split("/",expand=True)
# Out:
#                   0                  1     2
# 0      St Louis, MO               None  None
# 1     Montreal, PQ    Chesterville, ON  None
# 2     Montreal, PQ    Chesterville, ON  None
# 3     Montreal, PQ    Chesterville, ON  None
# 4     Montreal, PQ    Chesterville, ON  None
# ...             ...                ...   ...
# 1304              ?               None  None
# 1305              ?               None  None
# 1306              ?               None  None
# 1307              ?               None  None
# 1308              ?               None  None
#
# [1309 rows x 3 columns]

# %%
titanic["home.dest"].str.split("/",expand=True)[0]
# Out:
# 0        St Louis, MO
# 1       Montreal, PQ
# 2       Montreal, PQ
# 3       Montreal, PQ
# 4       Montreal, PQ
#             ...
# 1304                ?
# 1305                ?
# 1306                ?
# 1307                ?
# 1308                ?
# Name: 0, Length: 1309, dtype: object

# %%
titanic["home"]= titanic["home.dest"].str.split("/",expand=True)[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["destination"]= titanic["home.dest"].str.split("/",expand=True)[1]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["home"].value_counts()
# Out:
# home
# ?                                564
# New York, NY                      64
# Cornwall                          19
# London                            14
# London                            13
#                                 ...
# Chelsea, London                    1
# Harrow-on-the-Hill, Middlesex      1
# Copenhagen, Denmark                1
# Frankfort, KY                      1
# Antwerp, Belgium                   1
# Name: count, Length: 339, dtype: int64

# %%
titanic["destination"].value_counts()
# Out:
# destination
#  Akron, OH          11
#  Montreal, PQ        9
#  New York, NY        9
#  Detroit, MI         6
#  Cooperstown, NY     5
#                     ..
#  Rochester, NY       1
#   New York, NY       1
#  Pennsylvania        1
#  Toledo, OH          1
#  Stanton, OH         1
# Name: count, Length: 77, dtype: int64

# %%
titanic["home.dest"].str.split("/",expand=True, n=1)
# Out:
#                   0                  1
# 0      St Louis, MO               None
# 1     Montreal, PQ    Chesterville, ON
# 2     Montreal, PQ    Chesterville, ON
# 3     Montreal, PQ    Chesterville, ON
# 4     Montreal, PQ    Chesterville, ON
# ...             ...                ...
# 1304              ?               None
# 1305              ?               None
# 1306              ?               None
# 1307              ?               None
# 1308              ?               None
#
# [1309 rows x 2 columns]

# %% [markdown]
# -------------------------------------------------
# --------------------------------------------------
# ---------------------------------------------
#
# Replacing Portions of Strings With Replace()

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.cabin
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304          ?
# 1305          ?
# 1306          ?
# 1307          ?
# 1308          ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic.cabin.replace("?","???")
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304        ???
# 1305        ???
# 1306        ???
# 1307        ???
# 1308        ???
# Name: cabin, Length: 1309, dtype: object

# %%
ufos = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/nuforc_reports.csv")

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
ufos["duration"]
# Out:
# 0          5 seconds
# 1        3-5 seconds
# 2                NaN
# 3         10 seconds
# 4          2 minutes
#             ...
# 88120      3 minutes
# 88121     20 seconds
# 88122     20 seconds
# 88123      2 minutes
# 88124      3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.replace("seconds","s")
# Out:
# 0              5 s
# 1            3-5 s
# 2              NaN
# 3             10 s
# 4        2 minutes
#            ...
# 88120    3 minutes
# 88121         20 s
# 88122         20 s
# 88123    2 minutes
# 88124    3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.replace("seconds|minutes","",regex=True)
# Out:
# 0          5
# 1        3-5
# 2         NaN
# 3         10
# 4          2
#          ...
# 88120      3
# 88121     20
# 88122     20
# 88123      2
# 88124      3
# Name: duration, Length: 88125, dtype: object

# %%
def abbrv(reo):
    print(reo)
    return "HI"

# %%
ufos["duration"].str.replace("seconds|minutes",abbrv, regex=True)
# Out:
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(4, 11), match='seconds'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(4, 11), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(3, 10), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(3, 10), match='seconds'>
# <re.Match object; span=(2, 9), match='seconds'>
# <re.Match object; span=(2, 9), match='minutes'>
# <re.Match object; span=(2, 9), match='minutes'>
# ...

# %%
def abbrv(reo):
    return reo.group()[0]

# %%
ufos["duration"].str.replace("seconds|minutes",abbrv, regex=True)
# Out:
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.replace("seconds|minutes|hours",abbrv, regex=True)
# Out:
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %% [markdown]
# ----------------------------------------
# --------------------------------------------
# --------------------------------------------------
# Testing Strings With Contains()

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
ufos["duration"].str.contains("5")
# Out:
# 0         True
# 1         True
# 2          NaN
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: duration, Length: 88125, dtype: object

# %%
ufos[ufos["duration"].str.contains("hour",na=False)]
# Out:
#                                                  summary             city  \
# 10     Metal orb of wires that was seen through a tel...       Brookville
# 14     Bright Circle of Light followed me from Oskalo...      Centerville
# 36     Looked like airplanes without windows,  wings,...        Morehouse
# 37     01/20/51     Palm Springs CA     light     hou...     Palm Springs
# 40     5/16/1958/ 1500 hours/ just getting dark,mount...       Cincinnati
# ...                                                  ...              ...
# 88013  Unidentified flying object seen multiple night...  New port richey
# 88018  On balcony enjoying a beautiful night by the b...         New York
# 88064  Unidentified object moving very slowly across ...    Pt. St. Lucie
# 88065              White circular object above Ft Pierce      Fort Pierce
# 88073                                Lights in Texas sky           Slocum
#
#       state            date_time     shape              duration  \
# ...

# %%
ufos[ufos["duration"].str.contains("day|week|month",na=False)]
# Out:
#                                                  summary  \
# 107    7 large yellow lights with red center  estimat...
# 116    Saw one large ship during the day around noon ...
# 286    film makers in hollywood where talking of film...
# 290                               End of the Century UFO
# 1355   A white ball of light made several appearances...
# ...                                                  ...
# 84021  The Beings and Craft of Taos County.  ((NUFORC...
# 84983  In 1967 I am a little kid now. I am sleeping I...
# 85717  There was a big bright colored triangle object...
# 86210  2 flying diamonds; red and gold lights; creaki...
# 87707  Lights seen from the night sky 1st night-flick...
#
#                           city state            date_time      shape  \
# 107                    Griffin    GA  1984-03-15T20:00:00     circle
# 116                  Knoxville    TN  1986-04-04T23:00:00  rectangle
# 286                    Arizona    AZ  1997-07-07T00:00:00   triangle
# ...

# %% [markdown]
# ----------------------------------------------
# --------------------------------------------------
# ----------------------------------------------------
# Apply, Map, & Applymap

# %% [markdown]
# -------------------------Applying Functions To Series
#
# pandas.Series.apply

# %%
import pandas as pd
