# %%
import pandas as pd

# %%
dates = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/billboard_charts.csv")
ufos = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/nuforc_reports.csv")

# %%
dates
ufo_reports
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
pd.to_datetime("2022-12-31")
# Out:
# Timestamp('2022-12-31 00:00:00')

# %%
pd.to_datetime("2022/12/31")
# Out:
# Timestamp('2022-12-31 00:00:00')

# %%
pd.to_datetime("December 31st 2019")
# Out:
# Timestamp('2019-12-31 00:00:00')

# %%
pd.to_datetime("December 31st 2019 4pm")
# Out:
# Timestamp('2019-12-31 16:00:00')

# %%
pd.to_datetime("December 31st 2019 4:50am")
# Out:
# Timestamp('2019-12-31 04:50:00')

# %%
pd.to_datetime("Dec 25 2019 4:50am")
# Out:
# Timestamp('2019-12-25 04:50:00')

# %%
pd.to_datetime("3:55:45 Apr. 2nd 90")
# Out:
# Timestamp('1990-04-02 03:55:45')

# %%
pd.to_datetime("10/11/12",dayfirst=True)
# Out:
# Timestamp('2012-11-10 00:00:00')

# %%
pd.to_datetime("10/11/12",yearfirst=True)
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
pd.to_datetime("10/11/12",yearfirst=True, dayfirst=True)
# Out:
# Timestamp('2010-12-11 00:00:00')

# %%
pd.to_datetime("10/11/12",format="%y/%m/%d")
# Out:
# Timestamp('2010-11-12 00:00:00')

# %%
meetings = ["Dec 11 2019 Meeting","Jan 6 2020 Meeting","Mar 19 2020 Meeting","Apr 15 2020 Meeting"]

# %%
pd.to_datetime(meetings,format="%b %d %Y Meeting")
# Out:
# DatetimeIndex(['2019-12-11', '2020-01-06', '2020-03-19', '2020-04-15'], dtype='datetime64[ns]', freq=None)

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: float64(2), object(10)
# memory usage: 8.1+ MB

# %%
pd.to_datetime(ufos["date_time"])
# Out:
# 0       2019-12-12 18:43:00
# 1       2019-03-22 18:30:00
# 2                       NaT
# 3       2019-04-17 02:00:00
# 4       2009-03-15 18:00:00
#                 ...
# 88120   2019-10-02 20:00:00
# 88121   2019-10-02 20:00:00
# 88122   2019-10-02 20:03:00
# 88123   2019-10-02 22:00:00
# 88124   2019-10-02 22:00:00
# Name: date_time, Length: 88125, dtype: datetime64[ns]

# %%
ufos["date"] = pd.to_datetime(ufos["date_time"])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(2), object(10)
# memory usage: 8.7+ MB

# %%
ufos.tail()
# Out:
#                                                  summary            city  \
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape    duration  \
# 88120    AZ  2019-10-02T20:00:00  formation   3 minutes
# 88121    MO  2019-10-02T20:00:00      light  20 seconds
# 88122    FL  2019-10-02T20:03:00  formation  20 seconds
# 88123    NC  2019-10-02T22:00:00   fireball   2 minutes
# 88124    CA  2019-10-02T22:00:00     sphere   3 minutes
#
#                                                    stats  \
# 88120  Occurred : 10/2/2019 20:00  (Entered as : 10/2...
# 88121  Occurred : 10/2/2019 20:00  (Entered as : 10/0...
# ...

# %%
ufos["date_time"] = pd.to_datetime(ufos["date_time"])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  date            86938 non-null  datetime64[ns]
# dtypes: datetime64[ns](2), float64(2), object(9)
# memory usage: 8.7+ MB

# %%
ufos = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/nuforc_reports.csv").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  object
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: float64(2), object(10)
# memory usage: 8.1+ MB

# %%
ufos = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/nuforc_reports.csv",parse_dates=["date_time"])

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 8.1+ MB

# %%
ufos["date_time"]
# Out:
# 0       2019-12-12 18:43:00
# 1       2019-03-22 18:30:00
# 2                       NaT
# 3       2019-04-17 02:00:00
# 4       2009-03-15 18:00:00
#                 ...
# 88120   2019-10-02 20:00:00
# 88121   2019-10-02 20:00:00
# 88122   2019-10-02 20:03:00
# 88123   2019-10-02 22:00:00
# 88124   2019-10-02 22:00:00
# Name: date_time, Length: 88125, dtype: datetime64[ns]

# %%
ufos["date_time"].dt

# %%
ufos["date_time"].dt.year.value_counts()
# Out:
# date_time
# 2014.0    8704
# 2012.0    8124
# 2013.0    7823
# 2015.0    6915
# 2019.0    5767
# 2016.0    5664
# 2011.0    5630
# 2008.0    5307
# 2017.0    5057
# 2009.0    4996
# 2010.0    4786
# 2007.0    4736
# 2006.0    3720
# 2018.0    3273
# 2005.0     566
# 2004.0     340
# 1997.0     300
# 2001.0     263
# 2000.0     243
# 2003.0     238
# 1998.0     229
# 2002.0     220
# 1999.0     220
# 1995.0     219
# 1996.0     200
# 1994.0     197
# 1978.0     195
# 1975.0     180
# 1977.0     169
# 1976.0     164
# 1974.0     148
# 1979.0     148
# 1993.0     148
# 1988.0     147
# 1973.0     138
# 1985.0     133
# 1990.0     132
# 1989.0     131
# 1980.0     131
# 1992.0     130
# 1987.0     124
# 1991.0     119
# 1986.0     111
# 1983.0     109
# 1981.0     106
# 1970.0     100
# 1982.0      97
# 1969.0      97
# 1972.0      92
# 1984.0      84
# 1971.0      68
# Name: count, dtype: int64

# %%
ufos["date_time"].dt.year.value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='date_time'>

# %%
ufos["date_time"].dt.month
# Out:
# 0        12.0
# 1         3.0
# 2         NaN
# 3         4.0
# 4         3.0
#          ...
# 88120    10.0
# 88121    10.0
# 88122    10.0
# 88123    10.0
# 88124    10.0
# Name: date_time, Length: 88125, dtype: float64

# %%
ufos["date_time"].dt.month.value_counts()
# Out:
# date_time
# 7.0     10682
# 8.0      8997
# 9.0      8498
# 10.0     8371
# 6.0      8357
# 11.0     7596
# 12.0     6525
# 5.0      6063
# 1.0      5979
# 4.0      5817
# 3.0      5494
# 2.0      4559
# Name: count, dtype: int64

# %%
ufos["date_time"].dt.month.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='date_time'>

# %%
ufos["date_time"].dt.day
# Out:
# 0        12.0
# 1        22.0
# 2         NaN
# 3        17.0
# 4        15.0
#          ...
# 88120     2.0
# 88121     2.0
# 88122     2.0
# 88123     2.0
# 88124     2.0
# Name: date_time, Length: 88125, dtype: float64

# %%
ufos["date_time"].dt.day.value_counts().plot(kind= "bar")
# Out:
# <Axes: xlabel='date_time'>

# %%
ufos["date_time"].dt.hour
# Out:
# 0        18.0
# 1        18.0
# 2         NaN
# 3         2.0
# 4        18.0
#          ...
# 88120    20.0
# 88121    20.0
# 88122    20.0
# 88123    22.0
# 88124    22.0
# Name: date_time, Length: 88125, dtype: float64

# %%
ufos["date_time"].dt.hour.value_counts()
# Out:
# date_time
# 21.0    12851
# 22.0    11660
# 20.0     9565
# 23.0     8194
# 19.0     6460
# 0.0      5577
# 18.0     4462
# 1.0      3285
# 17.0     2660
# 2.0      2216
# 3.0      2088
# 5.0      1874
# 4.0      1641
# 16.0     1612
# 6.0      1588
# 12.0     1408
# 15.0     1380
# 10.0     1334
# 13.0     1308
# 11.0     1301
# 14.0     1280
# 9.0      1126
# 7.0      1067
# 8.0      1001
# Name: count, dtype: int64

# %%
ufos["date_time"].dt.hour.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='date_time'>

# %%
ufos["date_time"].dt.dayofweek
# Out:
# 0        3.0
# 1        4.0
# 2        NaN
# 3        2.0
# 4        6.0
#         ...
# 88120    2.0
# 88121    2.0
# 88122    2.0
# 88123    2.0
# 88124    2.0
# Name: date_time, Length: 88125, dtype: float64

# %%
ufos["date_time"].dt.dayofweek.value_counts()
# Out:
# date_time
# 5.0    16305
# 4.0    12864
# 6.0    12652
# 3.0    11729
# 2.0    11646
# 1.0    10987
# 0.0    10755
# Name: count, dtype: int64

# %%
ufos["date_time"].dt.dayofweek.value_counts().plot(kind="bar")
#moday is zero
# Out:
# <Axes: xlabel='date_time'>

# %%
ufos["date_time"]
# Out:
# 0       2019-12-12 18:43:00
# 1       2019-03-22 18:30:00
# 2                       NaT
# 3       2019-04-17 02:00:00
# 4       2009-03-15 18:00:00
#                 ...
# 88120   2019-10-02 20:00:00
# 88121   2019-10-02 20:00:00
# 88122   2019-10-02 20:03:00
# 88123   2019-10-02 22:00:00
# 88124   2019-10-02 22:00:00
# Name: date_time, Length: 88125, dtype: datetime64[ns]

# %%
ufos["date_time"] < "1980"
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: date_time, Length: 88125, dtype: bool

# %%
ufos[ufos["date_time"] < "1980"]
# Out:
#                                                  summary  \
# 8      Ufos report in Irving Texas at 2200 hrs. On or...
# 15        Strange bright light hovered over mobile home.
# 31     Bright green round object quickly travelling e...
# 54     It was a full moon when my brother and I obser...
# 55              UFO over Orangevale, CA in May/June 1969
# ...                                                  ...
# 87166  VERY LARGE OBJECT- WHITE LIGHT ILLUMINATING MY...
# 87167  7 "PEARLESCENT" HIGH ALTITUDE CRAFT IN V FORMA...
# 87168  The even occurred North of Mt Calvary Rd on Ol...
# 87169  Triangle ship passed over silent with 7 green ...
# 87170  While trick or treating with Mom, my Grandma p...
#
#                         city state           date_time     shape  \
# 8                     Dallas    TX 1973-07-14 22:00:00      oval
# 15                Gray Court    SC 1975-07-17 00:00:00     light
# 31     N. Cascades Nat. Park    WA 1979-07-15 23:00:00     light
# ...

# %%
ufos[ufos["date_time"] < "1980"]
# Out:
#                                                  summary  \
# 8      Ufos report in Irving Texas at 2200 hrs. On or...
# 15        Strange bright light hovered over mobile home.
# 31     Bright green round object quickly travelling e...
# 54     It was a full moon when my brother and I obser...
# 55              UFO over Orangevale, CA in May/June 1969
# ...                                                  ...
# 87166  VERY LARGE OBJECT- WHITE LIGHT ILLUMINATING MY...
# 87167  7 "PEARLESCENT" HIGH ALTITUDE CRAFT IN V FORMA...
# 87168  The even occurred North of Mt Calvary Rd on Ol...
# 87169  Triangle ship passed over silent with 7 green ...
# 87170  While trick or treating with Mom, my Grandma p...
#
#                         city state           date_time     shape  \
# 8                     Dallas    TX 1973-07-14 22:00:00      oval
# 15                Gray Court    SC 1975-07-17 00:00:00     light
# 31     N. Cascades Nat. Park    WA 1979-07-15 23:00:00     light
# ...

# %%
ufos[ufos["date_time"] > "2019-12-23"]
# Out:
#                                                  summary        city state  \
# 85714  7-8 elongated objects flying in straight line ...  Wilmington    NC
#
#                 date_time  shape    duration  \
# 85714 2019-12-29 20:40:00  cigar  10 seconds
#
#                                                    stats  \
# 85714  Occurred : 11/29/2019 20:40  (Entered as : 12/...
#
#                                              report_link  \
# 85714  http://www.nuforc.org/webreports/151/S151158.html
#
#                                                     text               posted  \
# 85714  7-8 elongated objects flying in straight line ...  2019-12-01T00:00:00
#
#        city_latitude  city_longitude
# 85714      34.238375      -77.878468

# %%
ufos["date_time"].dt.hour == 0.0
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: date_time, Length: 88125, dtype: bool

# %%
ufos[ufos["date_time"].dt.hour == 2.0].head()
# Out:
#                                                summary         city state  \
# 3    I was driving towards the intersection of fall...       Ottawa    ON
# 14   Bright Circle of Light followed me from Oskalo...  Centerville    IA
# 148                              Strange Vibrations...    Indianola    IA
# 153  red ball ufo following small plane in tracy, c...        Tracy    CA
# 181  Silver disk flies through sky making zigzaggin...    Beaverton    OR
#
#               date_time     shape     duration  \
# 3   2019-04-17 02:00:00  teardrop   10 seconds
# 14  1999-08-15 02:30:00    circle       1 hour
# 148 1992-04-30 02:00:00   unknown    5 Minutes
# 153 1993-06-15 02:00:00     light    3 minutes
# 181 2015-04-16 02:30:00      disk  5-8 minutes
#
#                                                  stats  \
# 3    Occurred : 4/17/2019 02:00  (Entered as : 04-1...
# 14   Occurred : 8/15/1999 02:30  (Entered as : 08/1...
# 148  Occurred : 4/30/1992 02:00  (Entered as : 04/3...
# ...

# %%
ufos[ufos["date_time"].between("1988","1989")]
# Out:
#                                                  summary  \
# 128    Triangle craft with one large softwhite light ...
# 129    -Working the night shift,and always watching t...
# 130    one shining spiral  moves fast from southwest ...
# 134    Charbonneau Park, Rosemere, PQ. Diamond shaped...
# 750    what are those two 5-6 ft spheres floating on ...
# ...                                                  ...
# 81661  4 days of missing time while working in a remo...
# 82524  Very bright light moving from South to North, ...
# 82652  Beam of light with no sound; no indication of ...
# 84662  I was called to the back porch by my grandmoth...
# 87173  hovering saucer with colored lights flew and s...
#
#                           city state           date_time     shape  \
# 128                   Powhatan    VA 1988-03-08 05:20:00  triangle
# 129                     Woburn    MA 1988-06-20 01:00:00     light
# 130    Suzhou, Jiangsu (China)   NaN 1988-08-10 15:00:00    circle
# ...

# %%
ufos[ufos["date_time"].between("1988","1989")].sort_values("date_time")
# Out:
#                                                  summary             city  \
# 4128   fast moving Triangle with no sound and orange ...          Roselle
# 8389   Gigantic circular object hovering, and then wi...           Kenner
# 2071   Broad daylight gold colored flying object abou...  New Britain Twp
# 33511  A dull yellow light, low off the ground and no...    Williamsfield
# 16295  8 gliding craft in formation with a 9th "quant...        Cambridge
# ...                                                  ...              ...
# 82524  Very bright light moving from South to North, ...        Dry Creek
# 21938  large saucer shaped object with many colored l...           Dexter
# 8808   Black huge triangle craft with chevron shape o...         Stockton
# 4363   saw 5 objects doing amazing manuevers for 20 m...       Alamogordo
# 61675  Hi 3 of us were out joy riding in our small ky...           Aurora
#
#       state           date_time     shape        duration  \
# ...

# %%
ufos["date_time"].value_counts()
# Out:
# date_time
# 2015-11-07 18:00:00    104
# 2014-07-04 22:00:00     46
# 2010-07-04 22:00:00     37
# 2012-07-04 22:00:00     34
# 2015-07-04 22:00:00     27
#                       ...
# 2011-07-23 23:20:00      1
# 2011-07-23 23:47:00      1
# 2011-07-24 00:00:00      1
# 2011-07-24 00:02:00      1
# 2019-12-12 18:43:00      1
# Name: count, Length: 73122, dtype: int64

# %%
ufos["date_time"].dt.date.value_counts()
# Out:
# date_time
# 2015-11-07    290
# 2014-07-04    270
# 2010-07-04    210
# 2012-07-04    200
# 2013-07-04    185
#              ...
# 1980-09-12      1
# 1988-06-13      1
# 1981-07-29      1
# 2004-07-04      1
# 2003-09-07      1
# Name: count, Length: 8351, dtype: int64

# %%
recent_sightings = ufos[ufos["date_time"] .dt.year >= 2018]
recent_sightings["date_time"].dt.date.value_counts()
# Out:
# date_time
# 2019-11-11    77
# 2019-05-25    69
# 2019-05-26    67
# 2019-05-24    60
# 2019-07-04    57
#               ..
# 2019-12-29     1
# 2018-02-08     1
# 2019-05-09     1
# 2018-02-04     1
# 2018-02-07     1
# Name: count, Length: 719, dtype: int64

# %%
ufos[ufos["date_time"].between("2013-02-24","2019-05-26")]
# Out:
#                                                  summary  \
# 1      I think that I may caught a UFO on the NBC Nig...
# 3      I was driving towards the intersection of fall...
# 5      The object has flashing lights that are green,...
# 6      Description is the same as Washington DC event...
# 7      Apr. 10th we witnessed a very bright silvery r...
# ...                                                  ...
# 87312  We were celebrating new years on LSD-25  on th...
# 87313  Driving North on I-5 between Eugene and Salem,...
# 87314  Two triangular craft 15 car lengths apart abov...
# 87315  I was on the porch smoking when I happened to ...
# 87316  The crosses have a green light on the right an...
#
#                          city state           date_time      shape  \
# 1                  Rocky Hill    CT 2019-03-22 18:30:00     circle
# 3                      Ottawa    ON 2019-04-17 02:00:00   teardrop
# 5                  Kirbyville    TX 2019-04-02 20:25:00       disk
# ...

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  object
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](1), float64(2), object(9)
# memory usage: 8.1+ MB

# %%
ufos["posted"] = pd.to_datetime(ufos["posted"])

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
# dtypes: datetime64[ns](2), float64(2), object(8)
# memory usage: 8.1+ MB

# %%
ufos["time_before_reported"] = ufos["posted"] - ufos["date_time"]

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufos.sort_values("time_before_reported",ascending=False)
# Out:
#                                                  summary  \
# 86762  An incomplete report given on behalf of anothe...
# 87145                      Strange globe sighting--1969.
# 721    It was July 1969 on a clear summer evening in ...
# 1576   1969 olive branch Mississippi large round ligh...
# 1580   Six bright lights in &quot;V&quot; formation s...
# ...                                                  ...
# 87935  Two bright strobing lights were stationary and...
# 87936  Noticed an uneven, but steady line of craft fl...
# 87937  The stars moved in unison, without breaking fo...
# 87938  White dots in formation just appearing out of ...
# 87939  It can slowly through the gorge about eye leve...
#
#                           city state           date_time      shape  \
# 86762                  El Paso    TX 1969-06-01 00:00:00      other
# 87145             Philadelphia    PA 1969-07-04 01:30:00     sphere
# 721                 New Castle    PA 1969-07-01 21:00:00       disk
# ...

# %%
longest_wait = ufos.sort_values("time_before_reported",ascending=False).head(10)

# %%
longest_wait
# Out:
#                                                  summary          city state  \
# 86762  An incomplete report given on behalf of anothe...       El Paso    TX
# 87145                      Strange globe sighting--1969.  Philadelphia    PA
# 721    It was July 1969 on a clear summer evening in ...    New Castle    PA
# 1576   1969 olive branch Mississippi large round ligh...  Olive Branch    MS
# 1580   Six bright lights in &quot;V&quot; formation s...      Westport    MA
# 84984  Possible abduction in Colorado in 1969.  ((ano...       Boulder    CO
# 83965  Mysterious light in the sky over Southeren Cal...       Ontario    CA
# 722    Object blended with dark, bright light as if d...           NaN    IN
# 723    The dark object was within 15 feet of me, not ...   West Seneca    NY
# 1301   Elsmere Delaware Linden ave Park Large round n...       Elsmere    DE
#
#                 date_time      shape       duration  \
# 86762 1969-06-01 00:00:00      other      3 minutes
# ...

# %%
longest_wait["time_before_reported"].dt.days/365
# Out:
# 86762    50.583562
# 87145    50.282192
# 721      50.175342
# 1576     50.101370
# 1580     49.972603
# 84984    49.586301
# 83965    49.213699
# 722      49.180822
# 723      49.052055
# 1301     48.967123
# Name: time_before_reported, dtype: float64

# %%
charts = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/billboard_charts.csv", parse_dates=["date"])

# %%
charts
# Out:
#              date  rank                                 song  \
# 0      2021-11-06     1                           Easy On Me
# 1      2021-11-06     2                                 Stay
# 2      2021-11-06     3                        Industry Baby
# 3      2021-11-06     4                           Fancy Like
# 4      2021-11-06     5                           Bad Habits
# ...           ...   ...                                  ...
# 330082 1958-08-04    96                        Over And Over
# 330083 1958-08-04    97                     I Believe In You
# 330084 1958-08-04    98                      Little Serenade
# 330085 1958-08-04    99  I'll Get By (As Long As I Have You)
# 330086 1958-08-04   100                                 Judy
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 1       The Kid LAROI & Justin Bieber        2.0          1              16
# ...

# %%
charts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330087 entries, 0 to 330086
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   date            330087 non-null  datetime64[ns]
#  1   rank            330087 non-null  int64
#  2   song            330087 non-null  object
#  3   artist          330087 non-null  object
#  4   last-week       297775 non-null  float64
#  5   peak-rank       330087 non-null  int64
#  6   weeks-on-board  330087 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(2)
# memory usage: 17.6+ MB

# %%
charts["artist"].value_counts()
# Out:
# artist
# Taylor Swift                                      1023
# Elton John                                         889
# Madonna                                            857
# Drake                                              787
# Kenny Chesney                                      769
#                                                   ...
# RiceGum Featuring Alissa Violet                      1
# XXXTENTACION Featuring PnB Rock & Trippie Redd       1
# Justin Bieber Featuring Burna Boy                    1
# Justin Bieber Featuring BEAM                         1
# Frankie Vaughan                                      1
# Name: count, Length: 10205, dtype: int64

# %%
charts["artist"].value_counts().head(10)
# Out:
# artist
# Taylor Swift     1023
# Elton John        889
# Madonna           857
# Drake             787
# Kenny Chesney     769
# Tim McGraw        731
# Keith Urban       673
# Stevie Wonder     659
# Rod Stewart       657
# Mariah Carey      621
# Name: count, dtype: int64

# %%
charts["artist"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='artist'>

# %%
number_1s = charts["rank"] == 1
charts[number_1s]
# Out:
#              date  rank                             song  \
# 0      2021-11-06     1                       Easy On Me
# 100    2021-10-30     1                       Easy On Me
# 200    2021-10-23     1                    Industry Baby
# 300    2021-10-16     1                             Stay
# 400    2021-10-09     1                      My Universe
# ...           ...   ...                              ...
# 329587 1958-09-01     1  Nel Blu Dipinto Di Blu (Volaré)
# 329687 1958-08-25     1                      Little Star
# 329787 1958-08-18     1  Nel Blu Dipinto Di Blu (Volaré)
# 329887 1958-08-11     1                 Poor Little Fool
# 329987 1958-08-04     1                 Poor Little Fool
#
#                                artist  last-week  peak-rank  weeks-on-board
# 0                               Adele        1.0          1               3
# 100                             Adele       68.0          1               2
# ...

# %%
number_1s = charts["rank"] == 1
charts[number_1s]["artist"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: xlabel='artist'>

# %%
number_1s
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 330082    False
# 330083    False
# 330084    False
# 330085    False
# 330086    False
# Name: rank, Length: 330087, dtype: bool

# %%
charts[number_1s]["song"].value_counts()
# Out:
# song
# Old Town Road                               19
# Despacito                                   16
# One Sweet Day                               16
# Rockstar                                    15
# I'll Make Love To You                       14
#                                             ..
# Then Came You                                1
# You Haven't Done Nothin                      1
# You Ain't Seen Nothing Yet/Free Wheelin'     1
# Whatever Gets You Thru The Night             1
# I'll Take You There                          1
# Name: count, Length: 1104, dtype: int64

# %%
charts[charts["song"]=="Old Town Road"]
# Out:
#             date  rank           song                               artist  \
# 9445  2020-01-18    46  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 9514  2020-01-11    15  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 9633  2020-01-04    34  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 9740  2019-12-28    41  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 9838  2019-12-21    39  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 9930  2019-12-14    31  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 10019 2019-12-07    20  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 10126 2019-11-30    27  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 10220 2019-11-23    21  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 10317 2019-11-16    18  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# 10420 2019-11-09    21  Old Town Road  Lil Nas X Featuring Billy Ray Cyrus
# ...

# %%
charts[charts["song"]=="Old Town Road"]["rank"]
# Out:
# 9445     46
# 9514     15
# 9633     34
# 9740     41
# 9838     39
# 9930     31
# 10019    20
# 10126    27
# 10220    21
# 10317    18
# 10420    21
# 10517    18
# 10615    16
# 10713    14
# 10809    10
# 10909    10
# 11009    10
# 11110    11
# 11204     5
# 11304     5
# 11403     4
# 11502     3
# 11600     1
# 11700     1
# 11800     1
# 11900     1
# 12000     1
# 12100     1
# 12200     1
# 12300     1
# 12400     1
# 12500     1
# 12600     1
# 12700     1
# 12800     1
# 12900     1
# 13000     1
# 13100     1
# 13200     1
# 13300     1
# 13400     1
# 13514    15
# 13631    32
# 13750    51
# 13882    83
# Name: rank, dtype: int64

# %%
charts[charts["song"]=="Old Town Road"]["rank"].plot()
# Out:
# <Axes: >

# %%
charts[charts["song"]=="Old Town Road"]["rank"]
# Out:
# 9445     46
# 9514     15
# 9633     34
# 9740     41
# 9838     39
# 9930     31
# 10019    20
# 10126    27
# 10220    21
# 10317    18
# 10420    21
# 10517    18
# 10615    16
# 10713    14
# 10809    10
# 10909    10
# 11009    10
# 11110    11
# 11204     5
# 11304     5
# 11403     4
# 11502     3
# 11600     1
# 11700     1
# 11800     1
# 11900     1
# 12000     1
# 12100     1
# 12200     1
# 12300     1
# 12400     1
# 12500     1
# 12600     1
# 12700     1
# 12800     1
# 12900     1
# 13000     1
# 13100     1
# 13200     1
# 13300     1
# 13400     1
# 13514    15
# 13631    32
# 13750    51
# 13882    83
# Name: rank, dtype: int64

# %%
charts[charts["song"]=="Old Town Road"].set_index("date")["rank"]
# Out:
# date
# 2020-01-18    46
# 2020-01-11    15
# 2020-01-04    34
# 2019-12-28    41
# 2019-12-21    39
# 2019-12-14    31
# 2019-12-07    20
# 2019-11-30    27
# 2019-11-23    21
# 2019-11-16    18
# 2019-11-09    21
# 2019-11-02    18
# 2019-10-26    16
# 2019-10-19    14
# 2019-10-12    10
# 2019-10-05    10
# 2019-09-28    10
# 2019-09-21    11
# 2019-09-14     5
# 2019-09-07     5
# 2019-08-31     4
# 2019-08-24     3
# 2019-08-17     1
# 2019-08-10     1
# 2019-08-03     1
# 2019-07-27     1
# 2019-07-20     1
# 2019-07-13     1
# 2019-07-06     1
# 2019-06-29     1
# 2019-06-22     1
# 2019-06-15     1
# 2019-06-08     1
# 2019-06-01     1
# 2019-05-25     1
# 2019-05-18     1
# 2019-05-11     1
# 2019-05-04     1
# 2019-04-27     1
# 2019-04-20     1
# 2019-04-13     1
# 2019-04-06    15
# 2019-03-30    32
# 2019-03-23    51
# 2019-03-16    83
# Name: rank, dtype: int64

# %%
p= charts[charts["song"]=="Old Town Road"].set_index("date")["rank"].plot()

# %%
p= charts[charts["song"]=="Old Town Road"].set_index("date")["rank"].plot()
p.invert_yaxis()
