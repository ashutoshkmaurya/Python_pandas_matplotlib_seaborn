# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/titanic.csv")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["age"] = pd.to_numeric(titanic["age"],errors="coerce")

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/kc_house_data.csv"
                )

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
ufos = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/nuforc_reports.csv", parse_dates=['date_time',"posted"])

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
titanic.sex.value_counts()
# Out:
# sex
# male      843
# female    466
# Name: count, dtype: int64

# %%
titanic.sex.value_counts().plot()
# Out:
# <Axes: xlabel='sex'>

# %%
titanic.sex.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='sex'>

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses[["sqft_living","sqft_lot"]]
# Out:
#        sqft_living  sqft_lot
# 0             1180      5650
# 1             2570      7242
# 2              770     10000
# 3             1960      5000
# 4             1680      8080
# ...            ...       ...
# 21608         1530      1131
# 21609         2310      5813
# 21610         1020      1350
# 21611         1600      2388
# 21612         1020      1076
#
# [21613 rows x 2 columns]

# %%
houses[["sqft_living","sqft_lot"]].sort_values("sqft_living",ascending=False)
# Out:
#        sqft_living  sqft_lot
# 12777        13540    307752
# 7252         12050     27600
# 3914         10040     37325
# 9254          9890     31374
# 8092          9640     13068
# ...            ...       ...
# 4868           390      5900
# 18379          384    213444
# 860            380     15000
# 15381          370      1801
# 19452          290     20875
#
# [21613 rows x 2 columns]

# %%
houses[["sqft_living","sqft_lot"]].sort_values("sqft_living",ascending=False).head(10)
# Out:
#        sqft_living  sqft_lot
# 12777        13540    307752
# 7252         12050     27600
# 3914         10040     37325
# 9254          9890     31374
# 8092          9640     13068
# 4411          9200     35069
# 14556         8670     64033
# 18302         8020     21738
# 1164          8010     45517
# 1448          8000     23985

# %%
houses[["sqft_living","sqft_lot"]].sort_values("sqft_living",ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
houses[["sqft_living","sqft_lot","price"]].sort_values("sqft_living",ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: >

# %%
houses[["sqft_living","sqft_lot"]].sort_values("sqft_living",ascending=False).head(10).plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# --------------------------------------------------------------------------
# Changing Style Sheet

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-v0_8-notebook")

# %%
titanic.sex.value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='sex'>

# %%
plt.style.use("seaborn-v0_8-pastel")

# %%
titanic.sex.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
plt.style.use("Solarize_Light2")

# %%
titanic.sex.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %%
plt.style.use("fivethirtyeight")

# %%
titanic.sex.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# ------------------------------------------------------------------------
#
#
# Adding labels and Titles to Pandas Plot

# %%
titanic.sex.value_counts().plot(kind="bar",title="Sex Breakdown On Titanic")
# Out:
# <Axes: title={'center': 'Sex Breakdown On Titanic'}, xlabel='sex'>

# %%
import matplotlib.pyplot as plt
titanic.sex.value_counts().plot(kind="bar")
plt.title("My Title",loc="right")
# Out:
# Text(1.0, 1.0, 'My Title')

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufos["month"] = ufos["date_time"].dt.month

# %%
ufos["month"]
# Out:
# 0        12.0
# 1         3.0
# 2         NaN
# 3         4.0
# 4         3.0
#          ...
# 88120    10.0
# 88121    10.0
# 88122    10.0
# 88123    10.0
# 88124    10.0
# Name: month, Length: 88125, dtype: float64

# %%
ufos.month.value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='month'>

# %%
ufos.month.value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='month'>

# %%
sightings = ufos.month.value_counts().sort_index()
sightings.plot(
    kind="bar", 
    title = "UFO Sightings By Month",
    xlabel = "Month",
    ylabel = "Num Sightings",
    fontsize = "10"
)
# Out:
# <Axes: title={'center': 'UFO Sightings By Month'}, xlabel='Month', ylabel='Num Sightings'>

# %%
sightings = ufos.month.value_counts().sort_index()
sightings.plot(
    kind="bar", 
    title = "UFO Sightings By Month",
    fontsize = "10"
)
plt.xlabel("Month",fontsize= 24, color="olive")
plt.ylabel("Num Sightings", fontsize=24)
# Out:
# Text(0, 0.5, 'Num Sightings')

# %%
sightings
# Out:
# month
# 1.0      5979
# 2.0      4559
# 3.0      5494
# 4.0      5817
# 5.0      6063
# 6.0      8357
# 7.0     10682
# 8.0      8997
# 9.0      8498
# 10.0     8371
# 11.0     7596
# 12.0     6525
# Name: count, dtype: int64

# %%
months_dict = {1:"Jan", 2:"Feb",3:"Mar",4:"Apr",5:"May",6:"Jun",7:"Jul",8:"Aug",9:"Sept",10:"oct",11:"Nov",12:"Dec"}
sightings.rename(months_dict)
# Out:
# month
# Jan      5979
# Feb      4559
# Mar      5494
# Apr      5817
# May      6063
# Jun      8357
# Jul     10682
# Aug      8997
# Sept     8498
# oct      8371
# Nov      7596
# Dec      6525
# Name: count, dtype: int64

# %%
sightings
# Out:
# month
# 1.0      5979
# 2.0      4559
# 3.0      5494
# 4.0      5817
# 5.0      6063
# 6.0      8357
# 7.0     10682
# 8.0      8997
# 9.0      8498
# 10.0     8371
# 11.0     7596
# 12.0     6525
# Name: count, dtype: int64

# %%
sightings.rename(months_dict).plot(kind="bar")
# Out:
# <Axes: xlabel='month'>

# %%
sightings.rename(months_dict).plot(
    kind="bar", 
    title = "UFO Sightings By Month",
    fontsize = "10"
)
plt.xlabel("Month",fontsize= 24, color="olive")
plt.ylabel("Num Sightings", fontsize=24)
# Out:
# Text(0, 0.5, 'Num Sightings')

# %% [markdown]
# -------------------------------------------------------
# ------------------------------------------------------
# Closer Look at Pandas Bar Plots

# %%
salaries = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/Salaries.csv",low_memory=False)

# %%
salaries["BasePay"] = pd.to_numeric(salaries["BasePay"],errors="coerce").fillna(0)
salaries["OvertimePay"] = pd.to_numeric(salaries["OvertimePay"],errors="coerce").fillna(0)
salaries["otherPay"] = pd.to_numeric(salaries["OtherPay"],errors="coerce").fillna(0)

# %%
salaries
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
df = salaries[["EmployeeName","BasePay","OvertimePay","OtherPay"]]
df
# Out:
#              EmployeeName    BasePay  OvertimePay      OtherPay
# 0          NATHANIEL FORD  167411.18         0.00     400184.25
# 1            GARY JIMENEZ  155966.02    245131.88     137811.38
# 2          ALBERT PARDINI  212739.13    106088.18       16452.6
# 3       CHRISTOPHER CHONG   77916.00     56120.71      198306.9
# 4         PATRICK GARDNER  134401.60      9737.00     182234.59
# ...                   ...        ...          ...           ...
# 148649      Roy I Tillery       0.00         0.00          0.00
# 148650       Not provided       0.00         0.00  Not Provided
# 148651       Not provided       0.00         0.00  Not Provided
# 148652       Not provided       0.00         0.00  Not Provided
# 148653          Joe Lopez       0.00         0.00       -618.13
#
# [148654 rows x 4 columns]

# %%
df.set_index("EmployeeName",inplace=True)

# %%
df
# Out:
#                      BasePay  OvertimePay      OtherPay
# EmployeeName
# NATHANIEL FORD     167411.18         0.00     400184.25
# GARY JIMENEZ       155966.02    245131.88     137811.38
# ALBERT PARDINI     212739.13    106088.18       16452.6
# CHRISTOPHER CHONG   77916.00     56120.71      198306.9
# PATRICK GARDNER    134401.60      9737.00     182234.59
# ...                      ...          ...           ...
# Roy I Tillery           0.00         0.00          0.00
# Not provided            0.00         0.00  Not Provided
# Not provided            0.00         0.00  Not Provided
# Not provided            0.00         0.00  Not Provided
# Joe Lopez               0.00         0.00       -618.13
#
# [148654 rows x 3 columns]

# %%
df.head(10)
# Out:
#                       BasePay  OvertimePay   OtherPay
# EmployeeName
# NATHANIEL FORD      167411.18         0.00  400184.25
# GARY JIMENEZ        155966.02    245131.88  137811.38
# ALBERT PARDINI      212739.13    106088.18    16452.6
# CHRISTOPHER CHONG    77916.00     56120.71   198306.9
# PATRICK GARDNER     134401.60      9737.00  182234.59
# DAVID SULLIVAN      118602.00      8601.00  189082.74
# ALSON LEE            92492.01     89062.90  134426.14
# DAVID KUSHNER       256576.96         0.00    51322.5
# MICHAEL MORRIS      176932.64     86362.68   40132.23
# JOANNE HAYES-WHITE  285262.00         0.00   17115.73

# %%
df.head(10).plot(kind="bar", width = 0.2)
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df.head(10).plot(kind="bar", stacked=True)
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df["BasePay"]
# Out:
# EmployeeName
# NATHANIEL FORD       167411.18
# GARY JIMENEZ         155966.02
# ALBERT PARDINI       212739.13
# CHRISTOPHER CHONG     77916.00
# PATRICK GARDNER      134401.60
#                        ...
# Roy I Tillery             0.00
# Not provided              0.00
# Not provided              0.00
# Not provided              0.00
# Joe Lopez                 0.00
# Name: BasePay, Length: 148654, dtype: float64

# %%
df["BasePay"].sort_values(ascending=False).head()
# Out:
# EmployeeName
# Gregory P Suhr          319275.01
# Amy P Hart              318835.49
# Robert L Shaw           315572.01
# Joanne M Hayes-White    313686.01
# Harlan L Kelly-Jr       313312.52
# Name: BasePay, dtype: float64

# %%
df["BasePay"].sort_values(ascending=False).head().plot()
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df["BasePay"].sort_values(ascending=False).head().plot(kind="bar")
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df["BasePay"].sort_values(ascending=False).head().plot.bar()
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df["BasePay"].sort_values(ascending=False).head().plot.bar(color="red",title="Highest Pais SF Employees")
# Out:
# <Axes: title={'center': 'Highest Pais SF Employees'}, xlabel='EmployeeName'>

# %%
df["BasePay"].sort_values(ascending=False).head().plot.barh(color="red",title="Highest Pais SF Employees")
# Out:
# <Axes: title={'center': 'Highest Pais SF Employees'}, ylabel='EmployeeName'>

# %%
df
# Out:
#                      BasePay  OvertimePay      OtherPay
# EmployeeName
# NATHANIEL FORD     167411.18         0.00     400184.25
# GARY JIMENEZ       155966.02    245131.88     137811.38
# ALBERT PARDINI     212739.13    106088.18       16452.6
# CHRISTOPHER CHONG   77916.00     56120.71      198306.9
# PATRICK GARDNER    134401.60      9737.00     182234.59
# ...                      ...          ...           ...
# Roy I Tillery           0.00         0.00          0.00
# Not provided            0.00         0.00  Not Provided
# Not provided            0.00         0.00  Not Provided
# Not provided            0.00         0.00  Not Provided
# Joe Lopez               0.00         0.00       -618.13
#
# [148654 rows x 3 columns]

# %%
df.sort_index()
# Out:
#                         BasePay  OvertimePay OtherPay
# EmployeeName
# A BERNARD FATOOH       19969.37         0.00    70.54
# A Bernard  Fatooh      23908.50         0.00    15.12
# A Bernard Fatooh       18472.35         0.00    27.84
# A Bernard Fatooh       24061.35         0.00     0.00
# A ELIZABETH MARCHASIN  23591.80         0.00  2691.06
# ...                         ...          ...      ...
# Zuna T Luu             54703.00       264.36  1120.55
# Zuna T Luu             55026.00         0.00  1129.44
# Zuri  Jones            71986.90         0.00      0.0
# Zuri Jones             86588.52         0.00      0.0
# Zuri Jones             66667.54         0.00     0.00
#
# [148654 rows x 3 columns]

# %%
df.sort_values("OvertimePay",ascending=False).head().plot(kind="bar")
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
df.sort_values("OvertimePay",ascending=False).head().plot(kind="barh", stacked=True)
# Out:
# <Axes: ylabel='EmployeeName'>

# %%
df.sort_values("OvertimePay",ascending=False).head().plot(kind="barh", stacked=True)
plt.xlabel("Dollars")
# Out:
# Text(0.5, 0, 'Dollars')

# %% [markdown]
# -----------------------------------------------------------------------
# -------------------------------------------------------------------------
# ------------------------------------------------------------------------
# Pandas Histograam

# %%
df["BasePay"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["BasePay"].plot(kind="hist",bins = 200)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["BasePay"].plot(kind="hist",bins = 200, color = 'purple')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="hist", bins = 100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'BasePay'}>,
#         <Axes: title={'center': 'OvertimePay'}>]], dtype=object)

# %% [markdown]
# --------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Box Plots

# %%
df.plot(kind="box")
# Out:
# <Axes: >

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/kc_house_data.csv")

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses.bedrooms.plot(kind = "box")
# Out:
# <Axes: >

# %%
houses[["bedrooms","bathrooms"]].boxplot()
# Out:
# <Axes: >

# %%
houses[["bedrooms","bathrooms"]].boxplot(showfliers=False)
# Out:
# <Axes: >

# %% [markdown]
# --------------------------------------------------------------------
# ------------------------------------------------------------------
# Line Plots

# %%
titanic.plot()
# Out:
# <Axes: >

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  month           86938 non-null  float64
# dtypes: datetime64[ns](2), float64(3), object(8)
# memory usage: 8.7+ MB

# %%
ufos["year"] = ufos["date_time"].dt.year

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  month           86938 non-null  float64
#  13  year            86938 non-null  float64
# dtypes: datetime64[ns](2), float64(4), object(8)
# memory usage: 9.4+ MB

# %%
ufos.year.value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='year'>

# %%
ufos.year.value_counts().sort_index()
# Out:
# year
# 1969.0      97
# 1970.0     100
# 1971.0      68
# 1972.0      92
# 1973.0     138
# 1974.0     148
# 1975.0     180
# 1976.0     164
# 1977.0     169
# 1978.0     195
# 1979.0     148
# 1980.0     131
# 1981.0     106
# 1982.0      97
# 1983.0     109
# 1984.0      84
# 1985.0     133
# 1986.0     111
# 1987.0     124
# 1988.0     147
# 1989.0     131
# 1990.0     132
# 1991.0     119
# 1992.0     130
# 1993.0     148
# 1994.0     197
# 1995.0     219
# 1996.0     200
# 1997.0     300
# 1998.0     229
# 1999.0     220
# 2000.0     243
# 2001.0     263
# 2002.0     220
# 2003.0     238
# 2004.0     340
# 2005.0     566
# 2006.0    3720
# 2007.0    4736
# 2008.0    5307
# 2009.0    4996
# 2010.0    4786
# 2011.0    5630
# 2012.0    8124
# 2013.0    7823
# 2014.0    8704
# 2015.0    6915
# 2016.0    5664
# 2017.0    5057
# 2018.0    3273
# 2019.0    5767
# Name: count, dtype: int64

# %%
ufos.year.value_counts().sort_index().plot(kind="line")
# Out:
# <Axes: xlabel='year'>

# %%
ufos.year.value_counts().sort_index().plot(kind="line", color = "olive")
# Out:
# <Axes: xlabel='year'>

# %%
ufos.year.value_counts().sort_index().plot(kind="line", color = "olive", linewidth = 6)
# Out:
# <Axes: xlabel='year'>

# %%
ufos.year.value_counts().sort_index().plot(kind="line", color = "olive", linewidth = 6, linestyle = ":")
# Out:
# <Axes: xlabel='year'>

# %%
df.plot.line()
# Out:
# <Axes: xlabel='EmployeeName'>

# %%
houses.plot.line(y="price")
# Out:
# <Axes: >

# %%
houses.plot.line(x= "bedrooms", y="price")
# Out:
# <Axes: xlabel='bedrooms'>

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Pandas Scatter Plots

# %%
houses.plot.scatter(x="bedrooms",y="bathrooms")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %%
houses.plot.scatter(x="bedrooms",y="bathrooms", marker = "X")
# Out:
# <Axes: xlabel='bedrooms', ylabel='bathrooms'>

# %%
houses["bedrooms"].plot.scatter()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 houses["bedrooms"].plot.scatter()
#
# TypeError: PlotAccessor.scatter() missing 2 required positional arguments: 'x' and 'y'

# %% [markdown]
# -------------------------------
# ---------------------------------------------------
# -----------------------------------------------------------
# Multiple Plots on Same Axis

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufos[ufos["state"]== "CA"]
# Out:
#                                                  summary           city state  \
# 16     There were 4 lights in diagonal formation that...      Yuba City    CA
# 20                     Abnormal flashing object in SoCal  Santa Barbara    CA
# 23     7 stationary brightly lit objects seen  over h...   Marin County    CA
# 37     01/20/51     Palm Springs CA     light     hou...   Palm Springs    CA
# 45     bal of fire in the sky no reported air crashes...     El Cerrito    CA
# ...                                                  ...            ...   ...
# 88092  My mother and I have witnessed an M-shaped bli...    Bakersfield    CA
# 88100  Long duration, dash-like appearance, intermitt...      Escondido    CA
# 88112                              Don't care it happend        Hayfork    CA
# 88117  On history channel there should be a contact #...        Hayfork    CA
# 88124  Glowing lights in formation  just south of San...   Marin County    CA
#
# ...

# %%
ufos[ufos["state"]== "CA"].year.value_counts().sort_index().plot(kind="line")
# Out:
# <Axes: xlabel='year'>

# %%
ufos[ufos["state"]== "CA"].year.value_counts().sort_index().plot()
ufos[ufos["state"]== "TX"].year.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ufos[ufos["state"]== "CA"].year.value_counts().sort_index().plot()
plt.figure()
ufos[ufos["state"]== "TX"].year.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ufos[ufos["state"]== "CA"].year.value_counts().sort_index().plot(label="CA")
ufos[ufos["state"]== "TX"].year.value_counts().sort_index().plot(label="TX")
plt.legend()

# %%
ufos[ufos["state"]== "CA"].year.value_counts().sort_index().plot(label="CA")
ufos[ufos["state"]== "TX"].year.value_counts().sort_index().plot(label="TX")
plt.legend(loc="upper left")

# %%
ufos[ufos["state"]== "CA"].year.value_counts().sort_index().plot(label="CA")
ufos[ufos["state"]== "TX"].year.value_counts().sort_index().plot(label="TX")
plt.legend(loc="upper left")
plt.title("UFO Sightings by State")
# Out:
# Text(0.5, 1.0, 'UFO Sightings by State')

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state           date_time      shape     duration  \
# ...

# %%
ufos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 88125 entries, 0 to 88124
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   summary         88095 non-null  object
#  1   city            87888 non-null  object
#  2   state           82890 non-null  object
#  3   date_time       86938 non-null  datetime64[ns]
#  4   shape           85627 non-null  object
#  5   duration        84951 non-null  object
#  6   stats           88088 non-null  object
#  7   report_link     88125 non-null  object
#  8   text            88070 non-null  object
#  9   posted          86938 non-null  datetime64[ns]
#  10  city_latitude   72013 non-null  float64
#  11  city_longitude  72013 non-null  float64
#  12  month           86938 non-null  float64
#  13  year            86938 non-null  float64
# dtypes: datetime64[ns](2), float64(4), object(8)
# memory usage: 9.4+ MB

# %%
ufos["shape"]=="light"
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88120    False
# 88121     True
# 88122    False
# 88123    False
# 88124    False
# Name: shape, Length: 88125, dtype: bool

# %%
ufos[ufos["shape"]=="light"]
# Out:
#                                                  summary         city state  \
# 0      My wife was driving southeast on a fairly popu...      Chester    VA
# 15        Strange bright light hovered over mobile home.   Gray Court    SC
# 17     Star-like light that started bouncing in the a...      Abilene    TX
# 18     There where 4 bright lights in a shape of a di...       Leyner    CO
# 27     4 bright lights weaving in between one another...         Wall    NJ
# ...                                                  ...          ...   ...
# 88109  Orb of light appeared out of thin air, and zip...       Denton    TX
# 88116  Stepped out into our backyard to let out the d...  Clarksville    AR
# 88118  Bright light ascending directly upwards throug...       Calmar    AB
# 88119  there was a stationary orange light in the eas...  Morgan City    LA
# 88121  2 bright star like lights in the NNW skys,  ((...      Bolivar    MO
#
# ...

# %%
ufos[ufos["shape"]=="light"].year
# Out:
# 0        2019.0
# 15       1975.0
# 17       2019.0
# 18       2019.0
# 27       2015.0
#           ...
# 88109    2019.0
# 88116    2019.0
# 88118    2019.0
# 88119    2019.0
# 88121    2019.0
# Name: year, Length: 18230, dtype: float64

# %%
ufos[ufos["shape"]=="light"].year.value_counts().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ufos[ufos["shape"]=="light"].year.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ufos[ufos["shape"]=="light"].year.value_counts().sort_index().plot()
plt.xlim(2000,2018)
# Out:
# (2000.0, 2018.0)

# %%
ufos[ufos["shape"]=="light"].year.value_counts().sort_index().plot(label="light")
ufos[ufos["shape"]=="fireball"].year.value_counts().sort_index().plot(label="fireball")
plt.xlim(2000,2018)
plt.legend()

# %%
ufos[ufos["shape"]=="light"].year.value_counts().sort_index().plot(label="light")
ufos[ufos["shape"]=="fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"]=="circle"].year.value_counts().sort_index().plot(label="cirlce")
ufos[ufos["shape"]=="triangle"].year.value_counts().sort_index().plot(label="triangle")
ufos[ufos["shape"]=="formation"].year.value_counts().sort_index().plot(label="formation")
plt.xlim(2000,2018)
plt.legend()

# %%
plt.figure(figsize=(10,8))
ufos[ufos["shape"]=="light"].year.value_counts().sort_index().plot(label="light")
ufos[ufos["shape"]=="fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"]=="circle"].year.value_counts().sort_index().plot(label="cirlce")
ufos[ufos["shape"]=="triangle"].year.value_counts().sort_index().plot(label="triangle")
ufos[ufos["shape"]=="formation"].year.value_counts().sort_index().plot(label="formation")
plt.xlim(2000,2018)
plt.legend()

# %%
ufos[ufos["shape"]=="light"].year.value_counts().sort_index().plot(label="light", figsize = (10,8))
ufos[ufos["shape"]=="fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"]=="circle"].year.value_counts().sort_index().plot(label="cirlce")
ufos[ufos["shape"]=="triangle"].year.value_counts().sort_index().plot(label="triangle")
ufos[ufos["shape"]=="formation"].year.value_counts().sort_index().plot(label="formation")
plt.xlim(2000,2018)
plt.legend()

# %% [markdown]
# -----------------------------------------------------------
# ------------------------------------------------------
# -----------------------------------------------------
# Pandas Automatic Subplots

# %%
df
#df.info()
#df["otherPay"].astype(float)
# Out:
#                      BasePay  OvertimePay      OtherPay
# EmployeeName
# NATHANIEL FORD     167411.18         0.00     400184.25
# GARY JIMENEZ       155966.02    245131.88     137811.38
# ALBERT PARDINI     212739.13    106088.18       16452.6
# CHRISTOPHER CHONG   77916.00     56120.71      198306.9
# PATRICK GARDNER    134401.60      9737.00     182234.59
# ...                      ...          ...           ...
# Roy I Tillery           0.00         0.00          0.00
# Not provided            0.00         0.00  Not Provided
# Not provided            0.00         0.00  Not Provided
# Not provided            0.00         0.00  Not Provided
# Joe Lopez               0.00         0.00       -618.13
#
# [148654 rows x 3 columns]

# %%
df.replace('Not Provided', pd.NA, inplace=True)
# Out:
# C:\Users\ASHUTOSH KM\AppData\Local\Temp\ipykernel_828\1308352141.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace('Not Provided', pd.NA, inplace=True)

# %%
df
# Out:
#                      BasePay  OvertimePay   OtherPay
# EmployeeName
# NATHANIEL FORD     167411.18         0.00  400184.25
# GARY JIMENEZ       155966.02    245131.88  137811.38
# ALBERT PARDINI     212739.13    106088.18    16452.6
# CHRISTOPHER CHONG   77916.00     56120.71   198306.9
# PATRICK GARDNER    134401.60      9737.00  182234.59
# ...                      ...          ...        ...
# Roy I Tillery           0.00         0.00       0.00
# Not provided            0.00         0.00       <NA>
# Not provided            0.00         0.00       <NA>
# Not provided            0.00         0.00       <NA>
# Joe Lopez               0.00         0.00    -618.13
#
# [148654 rows x 3 columns]

# %%
df.dropna(inplace=True)
# Out:
# C:\Users\ASHUTOSH KM\AppData\Local\Temp\ipykernel_828\1379821321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
df
# Out:
#                      BasePay  OvertimePay   OtherPay
# EmployeeName
# NATHANIEL FORD     167411.18         0.00  400184.25
# GARY JIMENEZ       155966.02    245131.88  137811.38
# ALBERT PARDINI     212739.13    106088.18    16452.6
# CHRISTOPHER CHONG   77916.00     56120.71   198306.9
# PATRICK GARDNER    134401.60      9737.00  182234.59
# ...                      ...          ...        ...
# Carolyn A Wilson        0.00         0.00       0.00
# Joann Anderson          0.00         0.00       0.00
# Leon Walker             0.00         0.00       0.00
# Roy I Tillery           0.00         0.00       0.00
# Joe Lopez               0.00         0.00    -618.13
#
# [148650 rows x 3 columns]

# %%
df.plot(kind = "hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148650 entries, NATHANIEL FORD to Joe Lopez
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   BasePay      148650 non-null  float64
#  1   OvertimePay  148650 non-null  float64
#  2   OtherPay     148650 non-null  object
# dtypes: float64(2), object(1)
# memory usage: 4.5+ MB

# %%
df["OtherPay"] = df.astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_828\607645181.py in ?()
# ----> 1 df["OtherPay"] = df.astype(float)
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4077             self._setitem_frame(key, value)
#    4078         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4079             self._setitem_array(key, value)
#    4080         elif isinstance(value, DataFrame):
# -> 4081             self._set_item_frame_value(key, value)
#    4082         elif (
#    4083             is_list_like(value)
#    4084             and not self.columns.is_unique
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4205             loc = self.columns.get_loc(key)
#    4206             cols = self.columns[loc]
# ...

# %%
df["OtherPay"]
# Out:
# EmployeeName
# NATHANIEL FORD       400184.25
# GARY JIMENEZ         137811.38
# ALBERT PARDINI         16452.6
# CHRISTOPHER CHONG     198306.9
# PATRICK GARDNER      182234.59
#                        ...
# Carolyn A Wilson          0.00
# Joann Anderson            0.00
# Leon Walker               0.00
# Roy I Tillery             0.00
# Joe Lopez              -618.13
# Name: OtherPay, Length: 148650, dtype: object

# %%
df
# Out:
#                      BasePay  OvertimePay   OtherPay
# EmployeeName
# NATHANIEL FORD     167411.18         0.00  400184.25
# GARY JIMENEZ       155966.02    245131.88  137811.38
# ALBERT PARDINI     212739.13    106088.18    16452.6
# CHRISTOPHER CHONG   77916.00     56120.71   198306.9
# PATRICK GARDNER    134401.60      9737.00  182234.59
# ...                      ...          ...        ...
# Carolyn A Wilson        0.00         0.00       0.00
# Joann Anderson          0.00         0.00       0.00
# Leon Walker             0.00         0.00       0.00
# Roy I Tillery           0.00         0.00       0.00
# Joe Lopez               0.00         0.00    -618.13
#
# [148650 rows x 3 columns]

# %%
df["OtherPay"].value_counts()
# Out:
# OtherPay
# 0.0         30068
# 0.00        11532
# 624.0        1340
# 624.00        752
# 648.0         739
#             ...
# 13762.57        1
# 1797.68         1
# 4152.38         1
# 8767.26         1
# -618.13         1
# Name: count, Length: 84242, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148650 entries, NATHANIEL FORD to Joe Lopez
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   BasePay      148650 non-null  float64
#  1   OvertimePay  148650 non-null  float64
#  2   OtherPay     148650 non-null  object
# dtypes: float64(2), object(1)
# memory usage: 8.6+ MB

# %%
df["OtherPay"] = pd.to_numeric(df["OtherPay"],errors="coerce")
# Out:
# C:\Users\ASHUTOSH KM\AppData\Local\Temp\ipykernel_828\3417840444.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["OtherPay"] = pd.to_numeric(df["OtherPay"],errors="coerce")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 148650 entries, NATHANIEL FORD to Joe Lopez
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   BasePay      148650 non-null  float64
#  1   OvertimePay  148650 non-null  float64
#  2   OtherPay     148650 non-null  float64
# dtypes: float64(3)
# memory usage: 8.6+ MB

# %%
df.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(kind="hist",subplots=True,figsize = (5,5))
# Out:
# array([<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#        <Axes: ylabel='Frequency'>], dtype=object)

# %%
df.plot(kind="hist",subplots=True, sharex = False,figsize = (5,5))
plot.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[133], line 2
#       1 df.plot(kind="hist",subplots=True, sharex = False,figsize = (5,5))
# ----> 2 plot.tight_layout()
#
# NameError: name 'plot' is not defined

# %%
df.plot(kind="hist",subplots=True, sharex = False,layout =(1,3) ,figsize = (10,3))
plot.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[135], line 2
#       1 df.plot(kind="hist",subplots=True, sharex = False,layout =(1,3) ,figsize = (10,3))
# ----> 2 plot.tight_layout()
#
# NameError: name 'plot' is not defined

# %%
axs = df.plot(kind="hist",subplots=True, sharex = False,layout =(1,3) ,figsize = (10,3))
plt.tight_layout()
axs[0][2].set_xlim(0,50000)
# Out:
# (0.0, 50000.0)

# %%
axs = df.plot(kind="hist",subplots=True, sharex = False,layout =(1,3) ,figsize = (10,3))
plt.tight_layout()
axs[0][2].set_xlim(0,50000)
axs[0][1].set_title("Middle")
axs[0][0].set_title("First")
axs[0][2].set_title("Third")
# Out:
# Text(0.5, 1.0, 'Third')

# %% [markdown]
# -------------------------------------------------
# -----------------------------------------------------
# ----------------------------------------------------
# Manual Subplotes With Pandas

# %%
ufos.year
# Out:
# 0        2019.0
# 1        2019.0
# 2           NaN
# 3        2019.0
# 4        2009.0
#           ...
# 88120    2019.0
# 88121    2019.0
# 88122    2019.0
# 88123    2019.0
# 88124    2019.0
# Name: year, Length: 88125, dtype: float64

# %%
ufos.year.value_counts()
# Out:
# year
# 2014.0    8704
# 2012.0    8124
# 2013.0    7823
# 2015.0    6915
# 2019.0    5767
# 2016.0    5664
# 2011.0    5630
# 2008.0    5307
# 2017.0    5057
# 2009.0    4996
# 2010.0    4786
# 2007.0    4736
# 2006.0    3720
# 2018.0    3273
# 2005.0     566
# 2004.0     340
# 1997.0     300
# 2001.0     263
# 2000.0     243
# 2003.0     238
# 1998.0     229
# 2002.0     220
# 1999.0     220
# 1995.0     219
# 1996.0     200
# 1994.0     197
# 1978.0     195
# 1975.0     180
# 1977.0     169
# 1976.0     164
# 1974.0     148
# 1979.0     148
# 1993.0     148
# 1988.0     147
# 1973.0     138
# 1985.0     133
# 1990.0     132
# 1989.0     131
# 1980.0     131
# 1992.0     130
# 1987.0     124
# 1991.0     119
# 1986.0     111
# 1983.0     109
# 1981.0     106
# 1970.0     100
# 1982.0      97
# 1969.0      97
# 1972.0      92
# 1984.0      84
# 1971.0      68
# Name: count, dtype: int64

# %%
ufos.year.value_counts().sort_index()
# Out:
# year
# 1969.0      97
# 1970.0     100
# 1971.0      68
# 1972.0      92
# 1973.0     138
# 1974.0     148
# 1975.0     180
# 1976.0     164
# 1977.0     169
# 1978.0     195
# 1979.0     148
# 1980.0     131
# 1981.0     106
# 1982.0      97
# 1983.0     109
# 1984.0      84
# 1985.0     133
# 1986.0     111
# 1987.0     124
# 1988.0     147
# 1989.0     131
# 1990.0     132
# 1991.0     119
# 1992.0     130
# 1993.0     148
# 1994.0     197
# 1995.0     219
# 1996.0     200
# 1997.0     300
# 1998.0     229
# 1999.0     220
# 2000.0     243
# 2001.0     263
# 2002.0     220
# 2003.0     238
# 2004.0     340
# 2005.0     566
# 2006.0    3720
# 2007.0    4736
# 2008.0    5307
# 2009.0    4996
# 2010.0    4786
# 2011.0    5630
# 2012.0    8124
# 2013.0    7823
# 2014.0    8704
# 2015.0    6915
# 2016.0    5664
# 2017.0    5057
# 2018.0    3273
# 2019.0    5767
# Name: count, dtype: int64

# %%
ufos.year.value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='year'>

# %%
ufos.month.value_counts().sort_index().plot(kind="bar")
# Out:
# <Axes: xlabel='month'>

# %%
fig, axs = plt.subplots(1,2)
ufos.year.value_counts().sort_index().plot(ax=axs[1])
ufos.month.value_counts().sort_index().plot(kind="bar",ax=axs[0])
# Out:
# <Axes: xlabel='month'>

# %%
fig, axs = plt.subplots(1,2)
ufos.year.value_counts().sort_index().plot(ax=axs[0])
axs[0].set_title("Sightings By Year")
ufos.month.value_counts().sort_index().plot(kind="bar",ax=axs[1])
axs[1].set_title("Sightings By Month")
# Out:
# Text(0.5, 1.0, 'Sightings By Month')

# %% [markdown]
# -------------------------------------------------
# ----------------------------------------------
# ------------------------------------------------
# Exporting Figures with SaveFig()
#
# matplotlib.pyplot.savefig

# %%
plt.figure(figsize=(10,8))
ufos[ufos["shape"]=="light"].year.value_counts().sort_index().plot(label="light")
ufos[ufos["shape"]=="fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"]=="circle"].year.value_counts().sort_index().plot(label="cirlce")
ufos[ufos["shape"]=="triangle"].year.value_counts().sort_index().plot(label="triangle")
ufos[ufos["shape"]=="formation"].year.value_counts().sort_index().plot(label="formation")
plt.xlim(2000,2018)
plt.legend()

# %%
plt.figure(figsize=(10,8))
ufos[ufos["shape"]=="light"].year.value_counts().sort_index().plot(label="light")
ufos[ufos["shape"]=="fireball"].year.value_counts().sort_index().plot(label="fireball")
ufos[ufos["shape"]=="circle"].year.value_counts().sort_index().plot(label="cirlce")
ufos[ufos["shape"]=="triangle"].year.value_counts().sort_index().plot(label="triangle")
ufos[ufos["shape"]=="formation"].year.value_counts().sort_index().plot(label="formation")
plt.xlim(2000,2018)
plt.legend()
plt.savefig("UFO_Shapes")
