# %%
import pandas as pd
houses = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/kc_house_data.csv")
titanic = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/titanic.csv")
netflix = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/netflix_titles.csv",sep="|", index_col=0)
btc = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/coin_Bitcoin.csv")
countries = pd.read_csv("C:/Users/ASHUTOSH KM/Desktop/Analytics + Python tutorials/data/DataAnalysis/data/world-happiness-report-2021.csv")

# %%
countries.set_index("Country name",inplace=True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
btc.drop(labels="Symbol",axis=1)
# Out:
#        SNo     Name                 Date          High           Low  \
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
btc.drop(labels="Symbol",axis=1)
# Out:
#        SNo     Name                 Date          High           Low  \
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...                  ...           ...           ...
# 2986  2987  Bitcoin  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin  2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# 0       134.444000    144.539993  0.000000e+00  1.603769e+09
# ...

# %%
btc.drop(labels=["Symbol","SNo","Name"],axis='columns')
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
btc.drop(columns=["SNo","Name","Symbol"])
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
btc[["Date","High","Low"]]
# Out:
#                      Date          High           Low
# 0     2013-04-29 23:59:59    147.488007    134.000000
# 1     2013-04-30 23:59:59    146.929993    134.050003
# 2     2013-05-01 23:59:59    139.889999    107.720001
# 3     2013-05-02 23:59:59    125.599998     92.281898
# 4     2013-05-03 23:59:59    108.127998     79.099998
# ...                   ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169
#
# [2991 rows x 3 columns]

# %%
btc.drop(columns=["SNo","Name","Symbol"],inplace=True)

# %%
btc
# Out:
#                      Date          High           Low          Open  \
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000
# ...                   ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177
# 2987  2021-07-03 23:59:59  34909.259899  33402.696536  33854.421362
# 2988  2021-07-04 23:59:59  35937.567147  34396.477458  34665.564866
# 2989  2021-07-05 23:59:59  35284.344430  33213.661034  35284.344430
# 2990  2021-07-06 23:59:59  35038.536363  33599.916169  33723.509655
#
#              Close        Volume     Marketcap
# 0       144.539993  0.000000e+00  1.603769e+09
# 1       139.000000  0.000000e+00  1.542813e+09
# ...

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.drop(labels="Denmark",axis=0)
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# Norway            Western Europe         7.392
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Switzerland                            0.036         7.643         7.500
# Iceland                                0.059         7.670         7.438
# ...

# %%
countries
# Out:
#               Regional indicator  Ladder score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 countries
#
# NameError: name 'countries' is not defined

# %%
countries
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
countries.drop(countries.index[0:3])
# Out:
#     Country name  Regional indicator  Ladder score  \
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# 5         Norway      Western Europe         7.392
# 6         Sweden      Western Europe         7.363
# 7     Luxembourg      Western Europe         7.324
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 3                             0.059         7.670         7.438
# 4                             0.027         7.518         7.410
# 5                             0.035         7.462         7.323
# 6                             0.036         7.433         7.293
# ...

# %%
countries.drop(countries.index[10:])
# Out:
#   Country name     Regional indicator  Ladder score  \
# 0      Finland         Western Europe         7.842
# 1      Denmark         Western Europe         7.620
# 2  Switzerland         Western Europe         7.571
# 3      Iceland         Western Europe         7.554
# 4  Netherlands         Western Europe         7.464
# 5       Norway         Western Europe         7.392
# 6       Sweden         Western Europe         7.363
# 7   Luxembourg         Western Europe         7.324
# 8  New Zealand  North America and ANZ         7.277
# 9      Austria         Western Europe         7.268
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
# ...

# %% [markdown]
# H1 *Add Static Columns*

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["sex"]
# Out:
# 0       female
# 1         male
# 2       female
# 3         male
# 4       female
#          ...
# 1304    female
# 1305    female
# 1306      male
# 1307      male
# 1308      male
# Name: sex, Length: 1309, dtype: object

# %%
titanic["species"] = "human"

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
houses.insert(0,"county","King County")

# %%
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King County  7129300520  20141013T000000  221900.0         3
# 1      King County  6414100192  20141209T000000  538000.0         3
# 2      King County  5631500400  20150225T000000  180000.0         2
# 3      King County  2487200875  20141209T000000  604000.0         4
# 4      King County  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King County   263000018  20140521T000000  360000.0         3
# 21609  King County  6600060120  20150223T000000  400000.0         4
# 21610  King County  1523300141  20140623T000000  402101.0         2
# 21611  King County   291310100  20150116T000000  400000.0         3
# 21612  King County  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  grade  \
# 0           1.00         1180      5650     1.0           0  ...      7
# ...

# %%
houses["sale_price"] = houses["price"]

# %%
houses
# Out:
#             county          id             date     price  bedrooms  \
# 0      King County  7129300520  20141013T000000  221900.0         3
# 1      King County  6414100192  20141209T000000  538000.0         3
# 2      King County  5631500400  20150225T000000  180000.0         2
# 3      King County  2487200875  20141209T000000  604000.0         4
# 4      King County  1954400510  20150218T000000  510000.0         3
# ...            ...         ...              ...       ...       ...
# 21608  King County   263000018  20140521T000000  360000.0         3
# 21609  King County  6600060120  20150223T000000  400000.0         4
# 21610  King County  1523300141  20140623T000000  402101.0         2
# 21611  King County   291310100  20150116T000000  400000.0         3
# 21612  King County  1523300157  20141015T000000  325000.0         2
#
#        bathrooms  sqft_living  sqft_lot  floors  waterfront  ...  sqft_above  \
# ...

# %%
houses.insert(3,"num_bedroom",houses["bedrooms"])

# %%
houses
# Out:
#             county          id             date  num_bedroom     price  \
# 0      King County  7129300520  20141013T000000            3  221900.0
# 1      King County  6414100192  20141209T000000            3  538000.0
# 2      King County  5631500400  20150225T000000            2  180000.0
# 3      King County  2487200875  20141209T000000            4  604000.0
# 4      King County  1954400510  20150218T000000            3  510000.0
# ...            ...         ...              ...          ...       ...
# 21608  King County   263000018  20140521T000000            3  360000.0
# 21609  King County  6600060120  20150223T000000            4  400000.0
# 21610  King County  1523300141  20140623T000000            2  402101.0
# 21611  King County   291310100  20150116T000000            3  400000.0
# 21612  King County  1523300157  20141015T000000            2  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  \
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.drop(columns=["species"],inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["sibsp"]
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Name: sibsp, Length: 1309, dtype: int64

# %%
titanic["parch"]
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1304    0
# 1305    0
# 1306    0
# 1307    0
# 1308    0
# Name: parch, Length: 1309, dtype: int64

# %%
titanic["sibsp"] + titanic["parch"]
# Out:
# 0       0
# 1       3
# 2       3
# 3       3
# 4       3
#        ..
# 1304    1
# 1305    1
# 1306    0
# 1307    0
# 1308    0
# Length: 1309, dtype: int64

# %%
titanic["num_relatives"] = titanic["sibsp"] + titanic["parch"]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.sort_values("num_relatives", ascending=False)
# Out:
#       pclass  survived                                    name     sex age  \
# 1177       3         0                     Sage, Mr. Frederick    male   ?
# 1179       3         0                   Sage, Mr. John George    male   ?
# 1173       3         0            Sage, Miss. Constance Gladys  female   ?
# 1170       3         0              Sage, Master. Thomas Henry    male   ?
# 1172       3         0                         Sage, Miss. Ada  female   ?
# ...      ...       ...                                     ...     ...  ..
# 598        2         1                    Wright, Miss. Marion  female  26
# 599        2         0  Yrois, Miss. Henriette ('Mrs Harbeck')  female  24
# 600        3         0                     Abbing, Mr. Anthony    male  42
# 604        3         1             Abelseth, Miss. Karen Marie  female  16
# 1308       3         0                      Zimmerman, Mr. Leo    male  29
#
#       sibsp  parch     ticket   fare cabin embarked boat body  \
# ...

# %%
titanic["survived"] == 0
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4        True
#         ...
# 1304     True
# 1305     True
# 1306     True
# 1307     True
# 1308     True
# Name: survived, Length: 1309, dtype: bool

# %%
titanic[titanic["survived"]==1].sort_values("num_relatives", ascending=False)
# Out:
#      pclass  survived                                               name  \
# 641       3         1                  Asplund, Master. Edvin Rojj Felix
# 625       3         1                    Andersson, Miss. Erna Alexandra
# 646       3         1  Asplund, Mrs. Carl Oscar (Selma Augusta Emilia...
# 643       3         1                     Asplund, Miss. Lillian Gertrud
# 111       1         1                     Fortune, Miss. Alice Elizabeth
# ..      ...       ...                                                ...
# 597       2         1                       Williams, Mr. Charles Eugene
# 598       2         1                               Wright, Miss. Marion
# 604       3         1                        Abelseth, Miss. Karen Marie
# 605       3         1                      Abelseth, Mr. Olaus Jorgensen
# 0         1         1                      Allen, Miss. Elisabeth Walton
#
#         sex age  sibsp  parch   ticket      fare        cabin embarked boat  \
# ...

# %%
houses
# Out:
#             county          id             date  num_bedroom     price  \
# 0      King County  7129300520  20141013T000000            3  221900.0
# 1      King County  6414100192  20141209T000000            3  538000.0
# 2      King County  5631500400  20150225T000000            2  180000.0
# 3      King County  2487200875  20141209T000000            4  604000.0
# 4      King County  1954400510  20150218T000000            3  510000.0
# ...            ...         ...              ...          ...       ...
# 21608  King County   263000018  20140521T000000            3  360000.0
# 21609  King County  6600060120  20150223T000000            4  400000.0
# 21610  King County  1523300141  20140623T000000            2  402101.0
# 21611  King County   291310100  20150116T000000            3  400000.0
# 21612  King County  1523300157  20141015T000000            2  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_above  \
# ...

# %%
houses["price_sqft"] = houses["price"] / houses["sqft_living"]

# %%
houses
# Out:
#             county          id             date  num_bedroom     price  \
# 0      King County  7129300520  20141013T000000            3  221900.0
# 1      King County  6414100192  20141209T000000            3  538000.0
# 2      King County  5631500400  20150225T000000            2  180000.0
# 3      King County  2487200875  20141209T000000            4  604000.0
# 4      King County  1954400510  20150218T000000            3  510000.0
# ...            ...         ...              ...          ...       ...
# 21608  King County   263000018  20140521T000000            3  360000.0
# 21609  King County  6600060120  20150223T000000            4  400000.0
# 21610  King County  1523300141  20140623T000000            2  402101.0
# 21611  King County   291310100  20150116T000000            3  400000.0
# 21612  King County  1523300157  20141015T000000            2  325000.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %%
houses.sort_values("price_sqft",ascending=False)
# Out:
#             county          id             date  num_bedroom      price  \
# 19336  King County  6021500970  20150407T000000            2   874950.0
# 4013   King County   724069059  20140509T000000            3  2400000.0
# 10446  King County  1118000320  20150508T000000            4  3400000.0
# 8623   King County  6303400395  20150130T000000            1   325000.0
# 9314   King County  4389200610  20141201T000000            2   903000.0
# ...            ...         ...              ...          ...        ...
# 1385   King County  3342700465  20150123T000000            3   250000.0
# 17197  King County  5111400086  20140512T000000            3   110000.0
# 13825  King County  5637200450  20141017T000000            5   257000.0
# 3785   King County   723049156  20140523T000000            3   149000.0
# 18262  King County  2891000610  20141211T000000            4   148900.0
#
#        bedrooms  bathrooms  sqft_living  sqft_lot  floors  ...  sqft_basement  \
# ...

# %%
houses.sort_values("price_sqft",ascending=False).head(50)["zipcode"].value_counts()
# Out:
# zipcode
# 98004    10
# 98112     4
# 98117     3
# 98040     3
# 98103     3
# 98119     3
# 98115     2
# 98008     2
# 98034     2
# 98006     2
# 98039     2
# 98107     2
# 98105     2
# 98198     1
# 98199     1
# 98136     1
# 98053     1
# 98122     1
# 98125     1
# 98118     1
# 98075     1
# 98146     1
# 98177     1
# Name: count, dtype: int64

# %%
houses.sort_values("price_sqft",ascending=False).head(50)["zipcode"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='zipcode'>

# %%
btc
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                  ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC  2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC  2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC  2021-07-06 23:59:59  35038.536363  33599.916169
#
# ...

# %%
btc.set_index("Date")
# Out:
#                       SNo     Name Symbol          High           Low  \
# Date
# 2013-04-29 23:59:59     1  Bitcoin    BTC    147.488007    134.000000
# 2013-04-30 23:59:59     2  Bitcoin    BTC    146.929993    134.050003
# 2013-05-01 23:59:59     3  Bitcoin    BTC    139.889999    107.720001
# 2013-05-02 23:59:59     4  Bitcoin    BTC    125.599998     92.281898
# 2013-05-03 23:59:59     5  Bitcoin    BTC    108.127998     79.099998
# ...                   ...      ...    ...           ...           ...
# 2021-07-02 23:59:59  2987  Bitcoin    BTC  33939.588699  32770.680780
# 2021-07-03 23:59:59  2988  Bitcoin    BTC  34909.259899  33402.696536
# 2021-07-04 23:59:59  2989  Bitcoin    BTC  35937.567147  34396.477458
# 2021-07-05 23:59:59  2990  Bitcoin    BTC  35284.344430  33213.661034
# 2021-07-06 23:59:59  2991  Bitcoin    BTC  35038.536363  33599.916169
#
#                              Open         Close        Volume     Marketcap
# Date
# ...

# %%
btc["Close"] - btc["Open"]
# Out:
# 0         10.095993
# 1         -5.000000
# 2        -22.010002
# 3        -11.169998
# 4         -8.500000
#            ...
# 2986     347.448412
# 2987     814.127040
# 2988     622.214900
# 2989   -1538.341974
# 2990     511.683796
# Length: 2991, dtype: float64

# %%
btc["change"] = btc["Close"] - btc["Open"]

# %%
btc.sort_values("change",ascending=False)
# Out:
#        SNo     Name Symbol                 Date          High           Low  \
# 2842  2843  Bitcoin    BTC  2021-02-08 23:59:59  46203.931437  38076.322807
# 2919  2920  Bitcoin    BTC  2021-04-26 23:59:59  54288.002155  48852.796843
# 2863  2864  Bitcoin    BTC  2021-03-01 23:59:59  49784.015290  45115.093115
# 2853  2854  Bitcoin    BTC  2021-02-19 23:59:59  56113.650547  50937.275722
# 2923  2924  Bitcoin    BTC  2021-04-30 23:59:59  57900.719988  53129.600877
# ...    ...      ...    ...                  ...           ...           ...
# 2911  2912  Bitcoin    BTC  2021-04-18 23:59:59  61057.456509  52829.535926
# 2824  2825  Bitcoin    BTC  2021-01-21 23:59:59  35552.679497  30250.749639
# 2857  2858  Bitcoin    BTC  2021-02-23 23:59:59  54204.929756  45290.590268
# 2942  2943  Bitcoin    BTC  2021-05-19 23:59:59  43546.116485  30681.496912
# 2935  2936  Bitcoin    BTC  2021-05-12 23:59:59  57939.362415  49150.533875
#
# ...

# %%
countries
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %% [markdown]
# *Modifying Data Frames*

# %%
mapper = {"Regional indicator":"regional_indicator", "Ladder score":"ladder_score"}

# %%
countries.rename(columns=mapper)
# Out:
#     Country name  regional_indicator  ladder_score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
countries
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
countries.rename(columns=mapper,inplace=True)

# %%
countries
# Out:
#     Country name  regional_indicator  ladder_score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
mapper = {"Finland": "finland", "Denmark": "denmark"}
countries.rename(index=mapper)
# Out:
#     Country name  regional_indicator  ladder_score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
countries
# Out:
#     Country name  regional_indicator  ladder_score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
countries.set_index("Country name",inplace=True)

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# Finland           Western Europe         7.842
# Denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Finland                                0.032         7.904         7.780
# Denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
mapper = {"Finland": "finland", "Denmark": "denmark"}
countries.rename(index=mapper)
# Out:
#               regional_indicator  ladder_score  \
# Country name
# finland           Western Europe         7.842
# denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finland                                0.032         7.904         7.780
# denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
mapper = {"Finland": "finland", "Denmark": "denmark"}
countries.rename(index=mapper,inplace=True)

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# finland           Western Europe         7.842
# denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finland                                0.032         7.904         7.780
# denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["sex"].replace("female","F",inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name   sex  \
# 0          1         1                    Allen, Miss. Elisabeth Walton     F
# 1          1         1                   Allison, Master. Hudson Trevor  male
# 2          1         0                     Allison, Miss. Helen Loraine     F
# 3          1         0             Allison, Mr. Hudson Joshua Creighton  male
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)     F
# ...      ...       ...                                              ...   ...
# 1304       3         0                             Zabour, Miss. Hileni     F
# 1305       3         0                            Zabour, Miss. Thamine     F
# 1306       3         0                        Zakarian, Mr. Mapriededer  male
# 1307       3         0                              Zakarian, Mr. Ortin  male
# 1308       3         0                               Zimmerman, Mr. Leo  male
#
# ...

# %%
titanic["sex"].replace("F","female",inplace=True)
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["sex"].replace(["female","male"],["F","M"])
# Out:
# 0       F
# 1       M
# 2       F
# 3       M
# 4       F
#        ..
# 1304    F
# 1305    F
# 1306    M
# 1307    M
# 1308    M
# Name: sex, Length: 1309, dtype: object

# %%
titanic["age"].replace("?","IDK").value_counts()
# Out:
# age
# IDK       263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: count, Length: 99, dtype: int64

# %%
titanic["age"].replace("?",None).value_counts()
# Out:
# age
# 24        47
# 22        43
# 21        41
# 30        40
# 18        39
#           ..
# 0.3333     1
# 22.5       1
# 70.5       1
# 0.6667     1
# 26.5       1
# Name: count, Length: 98, dtype: int64

# %%
titanic["age"].replace(["?"],[None]).value_counts(dropna=False)
# Out:
# age
# None      263
# 24         47
# 22         43
# 21         41
# 30         40
#          ...
# 66          1
# 0.6667      1
# 76          1
# 67          1
# 26.5        1
# Name: count, Length: 99, dtype: int64

# %%
titanic["age"].replace(["?"],[None],inplace=True)

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
countries.loc["Brazil":"Cambodia"]
# Out:
#                               regional_indicator  ladder_score  \
# Country name
# Brazil               Latin America and Caribbean         6.330
# Mexico               Latin America and Caribbean         6.317
# Jamaica              Latin America and Caribbean         6.309
# Lithuania             Central and Eastern Europe         6.255
# Cyprus                            Western Europe         6.223
# ...                                          ...           ...
# Ukraine       Commonwealth of Independent States         4.875
# Iraq                Middle East and North Africa         4.854
# Gabon                         Sub-Saharan Africa         4.852
# Burkina Faso                  Sub-Saharan Africa         4.834
# Cambodia                          Southeast Asia         4.830
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Brazil                                 0.043         6.415         6.245
# ...

# %%
countries.loc["Brazil",["ladder_score"]]
# Out:
# ladder_score    6.33
# Name: Brazil, dtype: object

# %%
countries.loc["Brazil",["ladder_score","Healthy life expectancy"]]
# Out:
# ladder_score                 6.33
# Healthy life expectancy    66.601
# Name: Brazil, dtype: object

# %%
countries.loc[["Brazil","Panama","Honduras"],["ladder_score","Healthy life expectancy"]]
# Out:
#               ladder_score  Healthy life expectancy
# Country name
# Brazil               6.330                   66.601
# Panama               6.180                   69.652
# Honduras             5.919                   67.300

# %%
countries.loc[["Brazil"]]
# Out:
#                        regional_indicator  ladder_score  \
# Country name
# Brazil        Latin America and Caribbean          6.33
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# Brazil                                 0.043         6.415         6.245
#
#               Logged GDP per capita  Social support  Healthy life expectancy  \
# Country name
# Brazil                        9.577           0.882                   66.601
#
#               Freedom to make life choices  Generosity  \
# Country name
# Brazil                               0.804      -0.071
#
#               Perceptions of corruption  Ladder score in Dystopia  \
# Country name
# Brazil                            0.756                      2.43
#
#               Explained by: Log GDP per capita  Explained by: Social support  \
# Country name
# Brazil                                   1.028                         0.944
#
# ...

# %%
countries.iloc["Brazil"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 countries.iloc["Brazil"]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1711, in _iLocIndexer._getitem_axis(self, key, axis)
#    1709 key = item_from_zerodim(key)
#    1710 if not is_integer(key):
# -> 1711     raise TypeError("Cannot index by location index with a non-integer key")
#    1713 # validate the location
#    1714 self._validate_integer(key, axis)
#
# TypeError: Cannot index by location index with a non-integer key

# %%
countries[countries.index == "Denmark"]
# Out:
# Empty DataFrame
# Columns: [regional_indicator, ladder_score, Standard error of ladder score, upperwhisker, lowerwhisker, Logged GDP per capita, Social support, Healthy life expectancy, Freedom to make life choices, Generosity, Perceptions of corruption, Ladder score in Dystopia, Explained by: Log GDP per capita, Explained by: Social support, Explained by: Healthy life expectancy, Explained by: Freedom to make life choices, Explained by: Generosity, Explained by: Perceptions of corruption, Dystopia + residual]
# Index: []

# %%
countries.loc[["Brazil","Panama","Honduras"],["regional_indicator"]] = "Scandinavia"

# %%
countries.loc[["Brazil","Panama","Honduras"],["regional_indicator"]]
# Out:
#              regional_indicator
# Country name
# Brazil              Scandinavia
# Panama              Scandinavia
# Honduras            Scandinavia

# %%
countries
# Out:
#               regional_indicator  ladder_score  \
# Country name
# finland           Western Europe         7.842
# denmark           Western Europe         7.620
# Switzerland       Western Europe         7.571
# Iceland           Western Europe         7.554
# Netherlands       Western Europe         7.464
# ...                          ...           ...
# Lesotho       Sub-Saharan Africa         3.512
# Botswana      Sub-Saharan Africa         3.467
# Rwanda        Sub-Saharan Africa         3.415
# Zimbabwe      Sub-Saharan Africa         3.145
# Afghanistan           South Asia         2.523
#
#               Standard error of ladder score  upperwhisker  lowerwhisker  \
# Country name
# finland                                0.032         7.904         7.780
# denmark                                0.035         7.687         7.552
# Switzerland                            0.036         7.643         7.500
# ...

# %%
countries.loc["finland"]
# Out:
# regional_indicator                            Western Europe
# ladder_score                                           7.842
# Standard error of ladder score                         0.032
# upperwhisker                                           7.904
# lowerwhisker                                            7.78
# Logged GDP per capita                                 10.775
# Social support                                         0.954
# Healthy life expectancy                                 72.0
# Freedom to make life choices                           0.949
# Generosity                                            -0.098
# Perceptions of corruption                              0.186
# Ladder score in Dystopia                                2.43
# Explained by: Log GDP per capita                       1.446
# Explained by: Social support                           1.106
# Explained by: Healthy life expectancy                  0.741
# ...

# %%
countries.loc["finland"] = "LOL"

# %%
countries.loc[["finland"]]
# Out:
#              regional_indicator ladder_score Standard error of ladder score  \
# Country name
# finland                     LOL          LOL                            LOL
#
#              upperwhisker lowerwhisker Logged GDP per capita Social support  \
# Country name
# finland               LOL          LOL                   LOL            LOL
#
#              Healthy life expectancy Freedom to make life choices Generosity  \
# Country name
# finland                          LOL                          LOL        LOL
#
#              Perceptions of corruption Ladder score in Dystopia  \
# Country name
# finland                            LOL                      LOL
#
#              Explained by: Log GDP per capita Explained by: Social support  \
# Country name
# finland                                   LOL                          LOL
#
#              Explained by: Healthy life expectancy  \
# Country name
# finland                                        LOL
#
# ...

# %%
countries
# Out:
#               regional_indicator ladder_score Standard error of ladder score  \
# Country name
# finland                      LOL          LOL                            LOL
# denmark           Western Europe         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland           Western Europe        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Lesotho       Sub-Saharan Africa        3.512                           0.12
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
#
# ...

# %%
countries.loc["finland",["upperwhisker","lowerwhisker"]]="MEOW"

# %%
countries
# Out:
#               regional_indicator ladder_score Standard error of ladder score  \
# Country name
# finland                      LOL          LOL                            LOL
# denmark           Western Europe         7.62                          0.035
# Switzerland       Western Europe        7.571                          0.036
# Iceland           Western Europe        7.554                          0.059
# Netherlands       Western Europe        7.464                          0.027
# ...                          ...          ...                            ...
# Lesotho       Sub-Saharan Africa        3.512                           0.12
# Botswana      Sub-Saharan Africa        3.467                          0.074
# Rwanda        Sub-Saharan Africa        3.415                          0.068
# Zimbabwe      Sub-Saharan Africa        3.145                          0.058
# Afghanistan           South Asia        2.523                          0.038
#
# ...
