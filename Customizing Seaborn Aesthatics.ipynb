# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#  'white',"dark","whitegrid","darkgrid","ticks"

# %%
tips = sns.load_dataset("tips")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.set_style("white")

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style("whitegrid")

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style("dark")
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style("darkgrid")
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style("ticks")
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style("ticks")
sns.lineplot(data=tips, x="total_bill", y="tip")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_theme(style="darkgrid")

# %%
sns.lineplot(data=tips, x="total_bill", y="tip")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ======================================================================================
# # Customizing Styles with set_style()

# %%
sns.axes_style()
# Out:
# {'axes.facecolor': '#EAEAF2',
#  'axes.edgecolor': 'white',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': 'white',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
sns.axes_style("white")
# Out:
# {'figure.facecolor': 'white',
#  'axes.labelcolor': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'axes.axisbelow': True,
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'lines.solid_capstyle': 'round',
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'xtick.top': False,
#  'ytick.right': False,
#  'axes.grid': False,
#  'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'grid.color': '.8',
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True,
#  'xtick.bottom': False,
#  'ytick.left': False}

# %%
sns.set_style({'axes.facecolor': '#CAD3C8'})

# %%
sns.lineplot(data=tips, x="total_bill", y="tip")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style({'axes.facecolor': '#CAD3C8', 'grid.color':'#2C3A47'})

# %%
sns.lineplot(data=tips, x="total_bill", y="tip")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style({'axes.facecolor': '#CAD3C8', 'grid.color':'#9AECDB'})

# %%
sns.lineplot(data=tips, x="total_bill", y="tip")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style({'axes.facecolor': '#FC427B', 'grid.color':'#9AECDB'})

# %%
sns.lineplot(data=tips, x="total_bill", y="tip")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style("ticks", {'axes.facecolor': '#FC427B', 'grid.color':'#9AECDB'})
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_style("darkgrid")

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ========================================================================================
# # Altering Spines With despine()

# %%
sns.set_style("white")

# %%
sns.scatterplot(data=tips, x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.histplot(data=tips, x="total_bill")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, x="total_bill")
sns.despine()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=tips, x="total_bill")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.histplot(data=tips, x="total_bill")
sns.despine(bottom=True)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.histplot(data=tips, x="total_bill")
sns.despine(bottom=True, top=False)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ==================================================================================
# # Changing Color Palettes

# %%
#  'white',"dark","whitegrid","darkgrid","ticks"

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.barplot(data=tips, x="day", y="total_bill")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_palette("muted")
sns.barplot(data=tips, x="day", y="total_bill")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_palette("pastel")
sns.barplot(data=tips, x="day", y="total_bill")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_palette("dark")
sns.barplot(data=tips,x="day", y="total_bill")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.set_palette("invalid")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\palettes.py:235, in color_palette(palette, n_colors, desat, as_cmap)
#     233 try:
#     234     # Perhaps a named matplotlib colormap?
# --> 235     palette = mpl_palette(palette, n_colors, as_cmap=as_cmap)
#     236 except (ValueError, KeyError):  # Error class changed in mpl36
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\palettes.py:406, in mpl_palette(name, n_colors, as_cmap)
#     405 else:
# --> 406     cmap = get_colormap(name)
#     408 if name in MPL_QUAL_PALS:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_compat.py:133, in get_colormap(name)
#     132 try:
# --> 133     return mpl.colormaps[name]
#     134 except AttributeError:
#
# ...

# %%
sns.color_palette("Blues")
# Out:
# [(0.8584083044982699, 0.9134486735870818, 0.9645674740484429),
#  (0.7309496347558632, 0.8394771241830065, 0.9213225682429834),
#  (0.5356862745098039, 0.746082276047674, 0.8642522106881968),
#  (0.32628988850442137, 0.6186236063052672, 0.802798923490965),
#  (0.16696655132641292, 0.48069204152249134, 0.7291503267973857),
#  (0.044059976931949255, 0.3338869665513264, 0.6244521337946944)]

# %%
sns.color_palette("ocean")
# Out:
# [(0.0, 0.28823529411764703, 0.1411764705882353),
#  (0.0, 0.07058823529411767, 0.28627450980392155),
#  (0.0, 0.14117647058823524, 0.42745098039215684),
#  (0.0, 0.35882352941176465, 0.5725490196078431),
#  (0.14117647058823524, 0.5705882352941176, 0.7137254901960784),
#  (0.5764705882352938, 0.7882352941176469, 0.8588235294117647)]

# %%
sns.color_palette("gist_rainbow")
# Out:
# [(1.0, 0.6009538950715422, 0.0),
#  (0.6147323794382618, 1.0, 0.0),
#  (0.0, 1.0, 0.14758591608686492),
#  (0.0, 1.0, 0.9276829011174367),
#  (0.0, 0.3058397271952257, 1.0),
#  (0.4827365728900258, 0.0, 1.0)]

# %%
sns.color_palette("terrain")
# Out:
# [(0.011764705882352955, 0.5764705882352941, 0.9764705882352941),
#  (0.1450980392156863, 0.8290196078431373, 0.42901960784313725),
#  (0.7098039215686275, 0.9419607843137255, 0.5419607843137255),
#  (0.8549019607843137, 0.8142745098039216, 0.5216470588235294),
#  (0.5725490196078431, 0.45286274509803925, 0.36917647058823533),
#  (0.7176470588235294, 0.6385882352941177, 0.6216470588235294)]

# %%
sns.color_palette("terrain",3)
# Out:
# [(0.00392156862745098, 0.8007843137254902, 0.4007843137254902),
#  (0.996078431372549, 0.9949803921568627, 0.5978823529411764),
#  (0.5058823529411764, 0.3675294117647059, 0.33788235294117647)]

# %%
sns.color_palette("terrain",10)
# Out:
# [(0.07973856209150328, 0.44052287581699345, 0.8405228758169935),
#  (0.0, 0.6607843137254902, 0.8176470588235294),
#  (0.08235294117647059, 0.8164705882352942, 0.41647058823529415),
#  (0.4588235294117647, 0.891764705882353, 0.49176470588235294),
#  (0.8196078431372549, 0.9639215686274509, 0.563921568627451),
#  (0.9098039215686274, 0.8845490196078432, 0.5512941176470588),
#  (0.7294117647058824, 0.6536470588235295, 0.4538823529411765),
#  (0.5411764705882354, 0.41270588235294114, 0.3522352941176471),
#  (0.6392156862745098, 0.5381960784313725, 0.5165490196078432),
#  (0.8196078431372549, 0.7690980392156863, 0.7582745098039215)]

# %%
sns.set_palette("terrain")

# %%
sns.barplot(data=tips,x="day", y="total_bill")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.scatterplot(data=tips,x="tip", y="total_bill", hue="sex")
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="day", y="total_bill", palette="Blues")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="day", y="total_bill", palette="ocean")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.barplot(data=tips,x="day", y="total_bill")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.kdeplot(data=tips, x="tip")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(data=tips, x="tip", palette="pastel")
# Out:
# C:\Users\ASHUTOSH KM\AppData\Local\Temp\ipykernel_6500\3024668925.py:1: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.kdeplot(data=tips, x="tip", palette="pastel")
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.kdeplot(data=tips, x="tip", color="black")
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='tip', ylabel='Density'>
